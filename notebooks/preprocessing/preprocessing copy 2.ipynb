# %% [markdown]
# ### Loading libraries

# %%
import pandas as pd
import numpy as np
from pybiomart import Dataset

# %% [markdown]
# ### Loading data

# %%
mrna_data = pd.read_csv('../../data/raw_data/tcga_paad_mrna_tpm_raw.csv')

# %%
mirna_data = pd.read_csv('../../data/raw_data/tcga_paad_mirna_raw.csv')

# %%
meth_data = pd.read_csv('../../data/raw_data/tcga_paad_dnamethylation_raw.csv')

# %%
clinical_data = pd.read_csv('../../data/raw_data/tcga_paad_clinical_raw.csv', sep=',')

# %% [markdown]
# ### Dimension of datasets

# %%
print("mRNA data shape:", mrna_data.shape)
# Out:
# mRNA data shape: (60660, 184)

# %%
print("miRNA data shape:", mirna_data.shape)
# Out:
# miRNA data shape: (1881, 551)

# %%
print("Methylation data shape:", meth_data.shape)
# Out:
# Methylation data shape: (485577, 196)

# %%
print("Clinical data shape:", clinical_data.shape)
# Out:
# Clinical data shape: (187, 77)

# %% [markdown]
# ### mRNA Preprocessing

# %%
mrna_data.head(2)
# Out:
#            Unnamed: 0  TCGA-HZ-A8P1-01A-11R-A37L-07  \
# 0  ENSG00000000003.15                       17.6270
# 1   ENSG00000000005.6                        0.0535
#
#    TCGA-FB-AAPS-01A-12R-A39D-07  TCGA-IB-AAUN-01A-12R-A38C-07  \
# 0                       23.7376                       28.3285
# 1                        3.3526                        0.1050
#
#    TCGA-3A-A9I7-01A-21R-A38C-07  TCGA-FB-AAPY-01A-11R-A41B-07  \
# 0                       23.2157                       17.9026
# 1                        0.0000                        0.1162
#
#    TCGA-2J-AABP-01A-11R-A41B-07  TCGA-2L-AAQM-01A-11R-A39D-07  \
# 0                        31.907                        4.7895
# 1                         0.000                        0.0985
#
#    TCGA-HZ-8519-01A-11R-2404-07  TCGA-PZ-A5RE-01A-11R-A32O-07  ...  \
# 0                       26.8066                       16.7029  ...
# 1                        4.4800                        0.1142  ...
#
#    TCGA-HZ-8005-01A-11R-2204-07  TCGA-HV-A5A6-01A-11R-A26U-07  \
# 0                       26.9536                       51.6905
# 1                        0.0000                        0.2062
#
#    TCGA-F2-A44H-01A-11R-A26U-07  TCGA-LB-A7SX-01A-11R-A33R-07  \
# 0                        23.039                       27.7489
# 1                         0.000                        0.0727
#
#    TCGA-OE-A75W-01A-12R-A32O-07  TCGA-HZ-7925-01A-11R-2156-07  \
# 0                       19.3546                       25.2659
# 1                        0.1251                        0.1097
#
#    TCGA-FB-AAPZ-01A-11R-A41B-07  TCGA-IB-7646-01A-11R-2156-07  \
# 0                       33.7614                       63.0141
# 1                        3.7782                        0.0000
#
#    TCGA-US-A776-01A-13R-A33R-07  TCGA-IB-7887-01A-11R-2156-07
# 0                       22.2781                        31.633
# 1                        0.0000                         0.000
#
# [2 rows x 184 columns]

# %%
mrna_data.set_index('Unnamed: 0', inplace=True)

# %%
mrna_data.head(2)
# Out:
#                     TCGA-HZ-A8P1-01A-11R-A37L-07  \
# Unnamed: 0
# ENSG00000000003.15                       17.6270
# ENSG00000000005.6                         0.0535
#
#                     TCGA-FB-AAPS-01A-12R-A39D-07  \
# Unnamed: 0
# ENSG00000000003.15                       23.7376
# ENSG00000000005.6                         3.3526
#
#                     TCGA-IB-AAUN-01A-12R-A38C-07  \
# Unnamed: 0
# ENSG00000000003.15                       28.3285
# ENSG00000000005.6                         0.1050
#
#                     TCGA-3A-A9I7-01A-21R-A38C-07  \
# Unnamed: 0
# ENSG00000000003.15                       23.2157
# ENSG00000000005.6                         0.0000
#
#                     TCGA-FB-AAPY-01A-11R-A41B-07  \
# Unnamed: 0
# ENSG00000000003.15                       17.9026
# ENSG00000000005.6                         0.1162
#
#                     TCGA-2J-AABP-01A-11R-A41B-07  \
# Unnamed: 0
# ENSG00000000003.15                        31.907
# ENSG00000000005.6                          0.000
#
#                     TCGA-2L-AAQM-01A-11R-A39D-07  \
# Unnamed: 0
# ENSG00000000003.15                        4.7895
# ENSG00000000005.6                         0.0985
#
#                     TCGA-HZ-8519-01A-11R-2404-07  \
# Unnamed: 0
# ENSG00000000003.15                       26.8066
# ENSG00000000005.6                         4.4800
#
#                     TCGA-PZ-A5RE-01A-11R-A32O-07  \
# Unnamed: 0
# ENSG00000000003.15                       16.7029
# ENSG00000000005.6                         0.1142
#
#                     TCGA-HZ-8002-01A-11R-2204-07  ...  \
# Unnamed: 0                                        ...
# ENSG00000000003.15                       49.0826  ...
# ENSG00000000005.6                         2.1962  ...
#
#                     TCGA-HZ-8005-01A-11R-2204-07  \
# Unnamed: 0
# ENSG00000000003.15                       26.9536
# ENSG00000000005.6                         0.0000
#
#                     TCGA-HV-A5A6-01A-11R-A26U-07  \
# Unnamed: 0
# ENSG00000000003.15                       51.6905
# ENSG00000000005.6                         0.2062
#
#                     TCGA-F2-A44H-01A-11R-A26U-07  \
# Unnamed: 0
# ENSG00000000003.15                        23.039
# ENSG00000000005.6                          0.000
#
#                     TCGA-LB-A7SX-01A-11R-A33R-07  \
# Unnamed: 0
# ENSG00000000003.15                       27.7489
# ENSG00000000005.6                         0.0727
#
#                     TCGA-OE-A75W-01A-12R-A32O-07  \
# Unnamed: 0
# ENSG00000000003.15                       19.3546
# ENSG00000000005.6                         0.1251
#
#                     TCGA-HZ-7925-01A-11R-2156-07  \
# Unnamed: 0
# ENSG00000000003.15                       25.2659
# ENSG00000000005.6                         0.1097
#
#                     TCGA-FB-AAPZ-01A-11R-A41B-07  \
# Unnamed: 0
# ENSG00000000003.15                       33.7614
# ENSG00000000005.6                         3.7782
#
#                     TCGA-IB-7646-01A-11R-2156-07  \
# Unnamed: 0
# ENSG00000000003.15                       63.0141
# ENSG00000000005.6                         0.0000
#
#                     TCGA-US-A776-01A-13R-A33R-07  TCGA-IB-7887-01A-11R-2156-07
# Unnamed: 0
# ENSG00000000003.15                       22.2781                        31.633
# ENSG00000000005.6                         0.0000                         0.000
#
# [2 rows x 183 columns]

# %% [markdown]
# Keep Only Primary Samples

# %%
mrna_data = mrna_data.filter(regex=r'^([^-]+-){3}01')

# %%
mrna_data.shape
# Out:
# (60660, 178)

# %% [markdown]
# Change column names TCGA-XX-XXXX-XXX-XXX-XXXX-XX to TCGA-XX-XXXX

# %%
mrna_data.columns = ['-'.join(col.split('-')[:3]) for col in mrna_data.columns]

# %%
mrna_data.head(4)
# Out:
#                     TCGA-HZ-A8P1  TCGA-FB-AAPS  TCGA-IB-AAUN  TCGA-3A-A9I7  \
# Unnamed: 0
# ENSG00000000003.15       17.6270       23.7376       28.3285       23.2157
# ENSG00000000005.6         0.0535        3.3526        0.1050        0.0000
# ENSG00000000419.13       74.7450       66.5831       98.7555       65.5567
# ENSG00000000457.14       12.4880        4.9393        5.9452        6.2651
#
#                     TCGA-FB-AAPY  TCGA-2J-AABP  TCGA-2L-AAQM  TCGA-HZ-8519  \
# Unnamed: 0
# ENSG00000000003.15       17.9026       31.9070        4.7895       26.8066
# ENSG00000000005.6         0.1162        0.0000        0.0985        4.4800
# ENSG00000000419.13       43.7482      169.0360       60.6797       78.7670
# ENSG00000000457.14        5.7371        3.3893        2.8819        9.9698
#
#                     TCGA-PZ-A5RE  TCGA-HZ-8002  ...  TCGA-HZ-8005  \
# Unnamed: 0                                      ...
# ENSG00000000003.15       16.7029       49.0826  ...       26.9536
# ENSG00000000005.6         0.1142        2.1962  ...        0.0000
# ENSG00000000419.13       76.6370      106.2281  ...      147.1985
# ENSG00000000457.14        4.2757       15.1009  ...        4.2848
#
#                     TCGA-HV-A5A6  TCGA-F2-A44H  TCGA-LB-A7SX  TCGA-OE-A75W  \
# Unnamed: 0
# ENSG00000000003.15       51.6905       23.0390       27.7489       19.3546
# ENSG00000000005.6         0.2062        0.0000        0.0727        0.1251
# ENSG00000000419.13       95.5208       39.4291       85.8273       67.9924
# ENSG00000000457.14        6.1584        4.5045        6.3166        3.0322
#
#                     TCGA-HZ-7925  TCGA-FB-AAPZ  TCGA-IB-7646  TCGA-US-A776  \
# Unnamed: 0
# ENSG00000000003.15       25.2659       33.7614       63.0141       22.2781
# ENSG00000000005.6         0.1097        3.7782        0.0000        0.0000
# ENSG00000000419.13       96.9183      107.4199      166.8463       92.6525
# ENSG00000000457.14        8.7800        6.4660        6.4675        8.1843
#
#                     TCGA-IB-7887
# Unnamed: 0
# ENSG00000000003.15       31.6330
# ENSG00000000005.6         0.0000
# ENSG00000000419.13      103.6155
# ENSG00000000457.14       11.3388
#
# [4 rows x 178 columns]

# %% [markdown]
# Remove Suffixes ENSGXXXXXXXXXXX.XX to ENSGXXXXXXXXXXX

# %%
mrna_data.index = mrna_data.index.str.replace(r'\..*$', '', regex=True)
mrna_data.head(4)
# Out:
#                  TCGA-HZ-A8P1  TCGA-FB-AAPS  TCGA-IB-AAUN  TCGA-3A-A9I7  \
# Unnamed: 0
# ENSG00000000003       17.6270       23.7376       28.3285       23.2157
# ENSG00000000005        0.0535        3.3526        0.1050        0.0000
# ENSG00000000419       74.7450       66.5831       98.7555       65.5567
# ENSG00000000457       12.4880        4.9393        5.9452        6.2651
#
#                  TCGA-FB-AAPY  TCGA-2J-AABP  TCGA-2L-AAQM  TCGA-HZ-8519  \
# Unnamed: 0
# ENSG00000000003       17.9026       31.9070        4.7895       26.8066
# ENSG00000000005        0.1162        0.0000        0.0985        4.4800
# ENSG00000000419       43.7482      169.0360       60.6797       78.7670
# ENSG00000000457        5.7371        3.3893        2.8819        9.9698
#
#                  TCGA-PZ-A5RE  TCGA-HZ-8002  ...  TCGA-HZ-8005  TCGA-HV-A5A6  \
# Unnamed: 0                                   ...
# ENSG00000000003       16.7029       49.0826  ...       26.9536       51.6905
# ENSG00000000005        0.1142        2.1962  ...        0.0000        0.2062
# ENSG00000000419       76.6370      106.2281  ...      147.1985       95.5208
# ENSG00000000457        4.2757       15.1009  ...        4.2848        6.1584
#
#                  TCGA-F2-A44H  TCGA-LB-A7SX  TCGA-OE-A75W  TCGA-HZ-7925  \
# Unnamed: 0
# ENSG00000000003       23.0390       27.7489       19.3546       25.2659
# ENSG00000000005        0.0000        0.0727        0.1251        0.1097
# ENSG00000000419       39.4291       85.8273       67.9924       96.9183
# ENSG00000000457        4.5045        6.3166        3.0322        8.7800
#
#                  TCGA-FB-AAPZ  TCGA-IB-7646  TCGA-US-A776  TCGA-IB-7887
# Unnamed: 0
# ENSG00000000003       33.7614       63.0141       22.2781       31.6330
# ENSG00000000005        3.7782        0.0000        0.0000        0.0000
# ENSG00000000419      107.4199      166.8463       92.6525      103.6155
# ENSG00000000457        6.4660        6.4675        8.1843       11.3388
#
# [4 rows x 178 columns]

# %% [markdown]
# Transpose to rows=samples, cols=features

# %%
mrna_data = mrna_data.T
mrna_data.head(4)
# Out:
# Unnamed: 0    ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# TCGA-HZ-A8P1          17.6270           0.0535          74.7450
# TCGA-FB-AAPS          23.7376           3.3526          66.5831
# TCGA-IB-AAUN          28.3285           0.1050          98.7555
# TCGA-3A-A9I7          23.2157           0.0000          65.5567
#
# Unnamed: 0    ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# TCGA-HZ-A8P1          12.4880           2.9219           5.0411
# TCGA-FB-AAPS           4.9393           1.6271          20.8365
# TCGA-IB-AAUN           5.9452           2.4666          11.4351
# TCGA-3A-A9I7           6.2651           2.0103           8.5584
#
# Unnamed: 0    ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# TCGA-HZ-A8P1          17.3686          88.4678           8.4902
# TCGA-FB-AAPS          53.0990          58.6452           6.5501
# TCGA-IB-AAUN          43.8692          39.2728          12.9230
# TCGA-3A-A9I7          26.9308          69.8377          13.0385
#
# Unnamed: 0    ENSG00000001167  ...  ENSG00000288661  ENSG00000288662  \
# TCGA-HZ-A8P1          33.2621  ...              0.0           0.0000
# TCGA-FB-AAPS          16.1345  ...              0.0           1.5273
# TCGA-IB-AAUN          29.5894  ...              0.0           0.0000
# TCGA-3A-A9I7          16.5639  ...              0.0           0.0000
#
# Unnamed: 0    ENSG00000288663  ENSG00000288665  ENSG00000288667  \
# TCGA-HZ-A8P1           0.5817              0.0              0.0
# TCGA-FB-AAPS           0.3698              0.0              0.0
# TCGA-IB-AAUN           0.2856              0.0              0.0
# TCGA-3A-A9I7           0.4439              0.0              0.0
#
# Unnamed: 0    ENSG00000288669  ENSG00000288670  ENSG00000288671  \
# TCGA-HZ-A8P1           0.0000          10.1338              0.0
# TCGA-FB-AAPS           0.0000           4.4120              0.0
# TCGA-IB-AAUN           0.0194          12.9956              0.0
# TCGA-3A-A9I7           0.0000           6.3161              0.0
#
# Unnamed: 0    ENSG00000288674  ENSG00000288675
# TCGA-HZ-A8P1           0.0492           0.6578
# TCGA-FB-AAPS           0.0476           1.5273
# TCGA-IB-AAUN           0.0161           0.8765
# TCGA-3A-A9I7           0.0550           1.1206
#
# [4 rows x 60660 columns]

# %% [markdown]
# Keep only valid Ensembl

# %%
mrna_data = mrna_data.loc[:, mrna_data.columns.str.match(r'^ENSG\d{11}$')]
mrna_data.shape
# Out:
# (178, 60660)

# %% [markdown]
# Change index name

# %%
mrna_data.index.name = 'patient_id'
mrna_data.columns.name = None
mrna_data.head(3)
# Out:
#               ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# patient_id
# TCGA-HZ-A8P1          17.6270           0.0535          74.7450
# TCGA-FB-AAPS          23.7376           3.3526          66.5831
# TCGA-IB-AAUN          28.3285           0.1050          98.7555
#
#               ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# patient_id
# TCGA-HZ-A8P1          12.4880           2.9219           5.0411
# TCGA-FB-AAPS           4.9393           1.6271          20.8365
# TCGA-IB-AAUN           5.9452           2.4666          11.4351
#
#               ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# patient_id
# TCGA-HZ-A8P1          17.3686          88.4678           8.4902
# TCGA-FB-AAPS          53.0990          58.6452           6.5501
# TCGA-IB-AAUN          43.8692          39.2728          12.9230
#
#               ENSG00000001167  ...  ENSG00000288661  ENSG00000288662  \
# patient_id                     ...
# TCGA-HZ-A8P1          33.2621  ...              0.0           0.0000
# TCGA-FB-AAPS          16.1345  ...              0.0           1.5273
# TCGA-IB-AAUN          29.5894  ...              0.0           0.0000
#
#               ENSG00000288663  ENSG00000288665  ENSG00000288667  \
# patient_id
# TCGA-HZ-A8P1           0.5817              0.0              0.0
# TCGA-FB-AAPS           0.3698              0.0              0.0
# TCGA-IB-AAUN           0.2856              0.0              0.0
#
#               ENSG00000288669  ENSG00000288670  ENSG00000288671  \
# patient_id
# TCGA-HZ-A8P1           0.0000          10.1338              0.0
# TCGA-FB-AAPS           0.0000           4.4120              0.0
# TCGA-IB-AAUN           0.0194          12.9956              0.0
#
#               ENSG00000288674  ENSG00000288675
# patient_id
# TCGA-HZ-A8P1           0.0492           0.6578
# TCGA-FB-AAPS           0.0476           1.5273
# TCGA-IB-AAUN           0.0161           0.8765
#
# [3 rows x 60660 columns]

# %% [markdown]
# Remove duplicate patient samples

# %%
mrna_data = mrna_data[~mrna_data.index.duplicated(keep='first')]
mrna_data.shape
# Out:
# (178, 60660)

# %% [markdown]
# Remove duplicate genes

# %%
mrna_data['ENSG00000002586'].head(5)
# Out:
#               ENSG00000002586  ENSG00000002586
# patient_id
# TCGA-HZ-A8P1         109.1017              0.0
# TCGA-FB-AAPS         448.7163              0.0
# TCGA-IB-AAUN         160.5556              0.0
# TCGA-3A-A9I7         218.1256              0.0
# TCGA-FB-AAPY         139.6332              0.0

# %%
mrna_data = mrna_data.loc[:, ~mrna_data.columns.duplicated(keep='first')]
mrna_data.shape
# Out:
# (178, 60616)

# %% [markdown]
# Count the total number of missing values in mrna_data

# %%
total_missing_mrna = mrna_data.isnull().sum().sum()
print(f"Total missing values in mrna_data: {total_missing_mrna}")
# Out:
# Total missing values in mrna_data: 0

# %%
mrna_data.shape
# Out:
# (178, 60616)

# %% [markdown]
# #### Gene Annotation using Biomart

# %% [markdown]
# Dataset from Biomart

# %%
dataset = Dataset(name='hsapiens_gene_ensembl', host='http://www.ensembl.org')

# %%
gene_annotation = dataset.query(attributes=['ensembl_gene_id', 'hgnc_symbol', 'external_gene_name', 'gene_biotype'])

# %%
gene_annotation.head(3)
# Out:
#     Gene stable ID HGNC symbol Gene name Gene type
# 0  ENSG00000210049       MT-TF     MT-TF   Mt_tRNA
# 1  ENSG00000211459     MT-RNR1   MT-RNR1   Mt_rRNA
# 2  ENSG00000210077       MT-TV     MT-TV   Mt_tRNA

# %%
gene_annotation.rename(columns={'Gene stable ID': 'ensembl_gene_id', 'HGNC symbol': 'hgnc_symbol', 'Gene name': 'external_gene_name', 'Gene type': 'gene_biotype'}, inplace=True)
gene_annotation.head(3)
# Out:
#    ensembl_gene_id hgnc_symbol external_gene_name gene_biotype
# 0  ENSG00000210049       MT-TF              MT-TF      Mt_tRNA
# 1  ENSG00000211459     MT-RNR1            MT-RNR1      Mt_rRNA
# 2  ENSG00000210077       MT-TV              MT-TV      Mt_tRNA

# %% [markdown]
# Create column gene_name

# %%
gene_annotation['gene_name'] = gene_annotation['hgnc_symbol'].fillna(gene_annotation['external_gene_name'])

# %%
nan_hgnc = gene_annotation[gene_annotation['hgnc_symbol'].isna()]
nan_hgnc.tail(3)
# Out:
#        ensembl_gene_id hgnc_symbol external_gene_name    gene_biotype  \
# 83129  ENSG00000310517         NaN               CAST  protein_coding
# 84128  ENSG00000284691         NaN                NaN  protein_coding
# 84473  ENSG00000286190         NaN                NaN  protein_coding
#
#       gene_name
# 83129      CAST
# 84128       NaN
# 84473       NaN

# %% [markdown]
# Remove Duplicates ensembl_gene_id

# %%
gene_annotation.shape
# Out:
# (86371, 5)

# %%
gene_annotation[gene_annotation.duplicated(subset=['ensembl_gene_id'], keep=False)].sort_values('ensembl_gene_id').head(10)
# Out:
#        ensembl_gene_id hgnc_symbol external_gene_name gene_biotype  gene_name
# 41363  ENSG00000230417   LINC00595          LINC00595       lncRNA  LINC00595
# 41364  ENSG00000230417   LINC00856          LINC00595       lncRNA  LINC00856
# 69485  ENSG00000290758     POLR2J4            POLR2J4       lncRNA    POLR2J4
# 69486  ENSG00000290758     RASA4CP            POLR2J4       lncRNA    RASA4CP

# %%
gene_annotation = gene_annotation.drop(index=[69486, 41364])
gene_annotation.shape
# Out:
# (86369, 5)

# %% [markdown]
# Filtering gene_annotation to keep only genes from mrna_data

# %%
gene_annotation = gene_annotation[gene_annotation["ensembl_gene_id"].isin(mrna_data.columns)]

# %%
gene_annotation.shape
# Out:
# (59359, 5)

# %% [markdown]
# Delete rows with NaN gene_name

# %%
gene_annotation = gene_annotation.dropna(subset=['gene_name'])
gene_annotation.shape
# Out:
# (42513, 5)

# %% [markdown]
# Count duplicate hgnc_symbol

# %%
gene_annotation[gene_annotation.duplicated(subset=['hgnc_symbol'], keep=False)].shape[0]
# Out:
# 1285

# %% [markdown]
# Duplicate hgnc_symbol

# %%
duplicate_hgnc = gene_annotation[gene_annotation.duplicated(subset=['hgnc_symbol'], keep=False)].sort_values('hgnc_symbol')
duplicate_hgnc.head(10)
# Out:
#        ensembl_gene_id hgnc_symbol external_gene_name  \
# 55565  ENSG00000214081    CYP4F30P           CYP4F30P
# 72485  ENSG00000282944    CYP4F30P           CYP4F30P
# 14894  ENSG00000285467     DHRS4L1            DHRS4L1
# 25365  ENSG00000225766     DHRS4L1            DHRS4L1
# 11250  ENSG00000271672      DUXAP8             DUXAP8
# 15135  ENSG00000206195      DUXAP8             DUXAP8
# 58636  ENSG00000224516     ECEL1P2            ECEL1P2
# 55564  ENSG00000244280     ECEL1P2            ECEL1P2
# 13475  ENSG00000149531      FRG1BP             FRG1BP
# 13484  ENSG00000287288      FRG1BP             FRG1BP
#
#                              gene_biotype gene_name
# 55565  transcribed_unprocessed_pseudogene  CYP4F30P
# 72485                              lncRNA  CYP4F30P
# 14894                              lncRNA   DHRS4L1
# 25365  transcribed_unprocessed_pseudogene   DHRS4L1
# 11250    transcribed_processed_pseudogene    DUXAP8
# 15135                              lncRNA    DUXAP8
# 58636                              lncRNA   ECEL1P2
# 55564  transcribed_unprocessed_pseudogene   ECEL1P2
# 13475  transcribed_unprocessed_pseudogene    FRG1BP
# 13484                              lncRNA    FRG1BP

# %%
print(gene_annotation.shape[0])
print(mrna_data.shape[1])
# Out:
# 42513
# 60616

# %% [markdown]
# Genes without duplicate hgnc_symbol

# %%
gene_annotation_without_duplicate_hgnc = gene_annotation.drop_duplicates(subset=['hgnc_symbol'], keep='first')

# %% [markdown]
# ### miRNA Preprocessing

# %%
mirna_data.head(2)
# Out:
#    Unnamed: 0      miRNA_ID  read_count_TCGA-3A-A9I7-01A-21R-A38N-13  \
# 0           1  hsa-let-7a-1                                    33829
# 1           2  hsa-let-7a-2                                    33801
#
#    reads_per_million_miRNA_mapped_TCGA-3A-A9I7-01A-21R-A38N-13  \
# 0                                        8974.295034
# 1                                        8966.867080
#
#   cross-mapped_TCGA-3A-A9I7-01A-21R-A38N-13  \
# 0                                         N
# 1                                         N
#
#    read_count_TCGA-Z5-AAPL-01A-12R-A41G-13  \
# 0                                    19534
# 1                                    19372
#
#    reads_per_million_miRNA_mapped_TCGA-Z5-AAPL-01A-12R-A41G-13  \
# 0                                        8188.083643
# 1                                        8120.177963
#
#   cross-mapped_TCGA-Z5-AAPL-01A-12R-A41G-13  \
# 0                                         N
# 1                                         N
#
#    read_count_TCGA-H6-A45N-11A-12R-A26Y-13  \
# 0                                     7771
# 1                                     7859
#
#    reads_per_million_miRNA_mapped_TCGA-H6-A45N-11A-12R-A26Y-13  ...  \
# 0                                        5924.427150            ...
# 1                                        5991.516275            ...
#
#   cross-mapped_TCGA-YH-A8SY-01A-11R-A37H-13  \
# 0                                         N
# 1                                         N
#
#    read_count_TCGA-2L-AAQJ-01A-12R-A39J-13  \
# 0                                    82896
# 1                                    82839
#
#    reads_per_million_miRNA_mapped_TCGA-2L-AAQJ-01A-12R-A39J-13  \
# 0                                        9887.730083
# 1                                        9880.931195
#
#   cross-mapped_TCGA-2L-AAQJ-01A-12R-A39J-13  \
# 0                                         N
# 1                                         N
#
#    read_count_TCGA-FB-AAPZ-01A-11R-A41G-13  \
# 0                                    42105
# 1                                    42072
#
#    reads_per_million_miRNA_mapped_TCGA-FB-AAPZ-01A-11R-A41G-13  \
# 0                                        7526.564186
# 1                                        7520.665205
#
#   cross-mapped_TCGA-FB-AAPZ-01A-11R-A41G-13  \
# 0                                         N
# 1                                         N
#
#    read_count_TCGA-IB-7646-01A-11R-2155-13  \
# 0                                    34641
# 1                                    34856
#
#    reads_per_million_miRNA_mapped_TCGA-IB-7646-01A-11R-2155-13  \
# 0                                        8094.175726
# 1                                        8144.412376
#
#   cross-mapped_TCGA-IB-7646-01A-11R-2155-13
# 0                                         N
# 1                                         N
#
# [2 rows x 551 columns]

# %% [markdown]
# Keep only miRNA_ID and reads_per_million columns

# %%
cols_to_keep = ['miRNA_ID'] + [col for col in mirna_data.columns if 'reads_per_million' in col]

# %%
mirna_data = mirna_data[cols_to_keep]

# %%
mirna_data.head(3)
# Out:
#        miRNA_ID  reads_per_million_miRNA_mapped_TCGA-3A-A9I7-01A-21R-A38N-13  \
# 0  hsa-let-7a-1                                        8974.295034
# 1  hsa-let-7a-2                                        8966.867080
# 2  hsa-let-7a-3                                        8912.749128
#
#    reads_per_million_miRNA_mapped_TCGA-Z5-AAPL-01A-12R-A41G-13  \
# 0                                        8188.083643
# 1                                        8120.177963
# 2                                        8289.942163
#
#    reads_per_million_miRNA_mapped_TCGA-H6-A45N-11A-12R-A26Y-13  \
# 0                                        5924.427150
# 1                                        5991.516275
# 2                                        6168.387604
#
#    reads_per_million_miRNA_mapped_TCGA-HZ-7922-01A-11R-2155-13  \
# 0                                        9848.547177
# 1                                        9847.060305
# 2                                        9834.669701
#
#    reads_per_million_miRNA_mapped_TCGA-H6-A45N-01A-11R-A26Y-13  \
# 0                                        6504.359195
# 1                                        6549.357332
# 2                                        6620.807078
#
#    reads_per_million_miRNA_mapped_TCGA-IB-7645-01A-22R-2203-13  \
# 0                                        8725.311259
# 1                                        8529.989984
# 2                                        8644.347828
#
#    reads_per_million_miRNA_mapped_TCGA-2J-AABF-01A-31R-A41G-13  \
# 0                                        8576.109395
# 1                                        8450.951735
# 2                                        8542.393454
#
#    reads_per_million_miRNA_mapped_TCGA-H6-8124-01A-11R-2401-13  \
# 0                                       13959.663507
# 1                                       13919.584508
# 2                                       13971.142923
#
#    reads_per_million_miRNA_mapped_TCGA-FB-AAQ0-01A-31R-A41G-13  ...  \
# 0                                        7682.726535            ...
# 1                                        7672.791804            ...
# 2                                        7707.894522            ...
#
#    reads_per_million_miRNA_mapped_TCGA-HZ-A49H-01A-11R-A26Y-13  \
# 0                                        6063.950022
# 1                                        6052.934976
# 2                                        6060.945919
#
#    reads_per_million_miRNA_mapped_TCGA-Q3-A5QY-01A-12R-A32J-13  \
# 0                                       13487.928421
# 1                                       13413.739287
# 2                                       13613.460365
#
#    reads_per_million_miRNA_mapped_TCGA-HZ-A4BH-01A-11R-A26Y-13  \
# 0                                        6820.952950
# 1                                        6857.068316
# 2                                        6820.144397
#
#    reads_per_million_miRNA_mapped_TCGA-2J-AAB8-01A-12R-A41G-13  \
# 0                                        7090.095676
# 1                                        7092.906194
# 2                                        7101.056699
#
#    reads_per_million_miRNA_mapped_TCGA-3A-A9I9-01A-11R-A38N-13  \
# 0                                       10235.626935
# 1                                       10091.713697
# 2                                       10266.080485
#
#    reads_per_million_miRNA_mapped_TCGA-IB-8126-01A-11R-2401-13  \
# 0                                        7929.784709
# 1                                        8027.054387
# 2                                        8031.666311
#
#    reads_per_million_miRNA_mapped_TCGA-YH-A8SY-01A-11R-A37H-13  \
# 0                                       14862.937130
# 1                                       14798.404418
# 2                                       14946.566256
#
#    reads_per_million_miRNA_mapped_TCGA-2L-AAQJ-01A-12R-A39J-13  \
# 0                                        9887.730083
# 1                                        9880.931195
# 2                                        9968.123951
#
#    reads_per_million_miRNA_mapped_TCGA-FB-AAPZ-01A-11R-A41G-13  \
# 0                                        7526.564186
# 1                                        7520.665205
# 2                                        7605.217274
#
#    reads_per_million_miRNA_mapped_TCGA-IB-7646-01A-11R-2155-13
# 0                                        8094.175726
# 1                                        8144.412376
# 2                                        8171.516801
#
# [3 rows x 184 columns]

# %%
mirna_data.shape
# Out:
# (1881, 184)

# %%
mirna_data.set_index('miRNA_ID', inplace=True)

# %%
mirna_data.head(2)
# Out:
#               reads_per_million_miRNA_mapped_TCGA-3A-A9I7-01A-21R-A38N-13  \
# miRNA_ID
# hsa-let-7a-1                                        8974.295034
# hsa-let-7a-2                                        8966.867080
#
#               reads_per_million_miRNA_mapped_TCGA-Z5-AAPL-01A-12R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                                        8188.083643
# hsa-let-7a-2                                        8120.177963
#
#               reads_per_million_miRNA_mapped_TCGA-H6-A45N-11A-12R-A26Y-13  \
# miRNA_ID
# hsa-let-7a-1                                        5924.427150
# hsa-let-7a-2                                        5991.516275
#
#               reads_per_million_miRNA_mapped_TCGA-HZ-7922-01A-11R-2155-13  \
# miRNA_ID
# hsa-let-7a-1                                        9848.547177
# hsa-let-7a-2                                        9847.060305
#
#               reads_per_million_miRNA_mapped_TCGA-H6-A45N-01A-11R-A26Y-13  \
# miRNA_ID
# hsa-let-7a-1                                        6504.359195
# hsa-let-7a-2                                        6549.357332
#
#               reads_per_million_miRNA_mapped_TCGA-IB-7645-01A-22R-2203-13  \
# miRNA_ID
# hsa-let-7a-1                                        8725.311259
# hsa-let-7a-2                                        8529.989984
#
#               reads_per_million_miRNA_mapped_TCGA-2J-AABF-01A-31R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                                        8576.109395
# hsa-let-7a-2                                        8450.951735
#
#               reads_per_million_miRNA_mapped_TCGA-H6-8124-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                                       13959.663507
# hsa-let-7a-2                                       13919.584508
#
#               reads_per_million_miRNA_mapped_TCGA-FB-AAQ0-01A-31R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                                        7682.726535
# hsa-let-7a-2                                        7672.791804
#
#               reads_per_million_miRNA_mapped_TCGA-HZ-A9TJ-01A-11R-A41D-13  \
# miRNA_ID
# hsa-let-7a-1                                        7299.262318
# hsa-let-7a-2                                        7385.848430
#
#               ...  \
# miRNA_ID      ...
# hsa-let-7a-1  ...
# hsa-let-7a-2  ...
#
#               reads_per_million_miRNA_mapped_TCGA-HZ-A49H-01A-11R-A26Y-13  \
# miRNA_ID
# hsa-let-7a-1                                        6063.950022
# hsa-let-7a-2                                        6052.934976
#
#               reads_per_million_miRNA_mapped_TCGA-Q3-A5QY-01A-12R-A32J-13  \
# miRNA_ID
# hsa-let-7a-1                                       13487.928421
# hsa-let-7a-2                                       13413.739287
#
#               reads_per_million_miRNA_mapped_TCGA-HZ-A4BH-01A-11R-A26Y-13  \
# miRNA_ID
# hsa-let-7a-1                                        6820.952950
# hsa-let-7a-2                                        6857.068316
#
#               reads_per_million_miRNA_mapped_TCGA-2J-AAB8-01A-12R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                                        7090.095676
# hsa-let-7a-2                                        7092.906194
#
#               reads_per_million_miRNA_mapped_TCGA-3A-A9I9-01A-11R-A38N-13  \
# miRNA_ID
# hsa-let-7a-1                                       10235.626935
# hsa-let-7a-2                                       10091.713697
#
#               reads_per_million_miRNA_mapped_TCGA-IB-8126-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                                        7929.784709
# hsa-let-7a-2                                        8027.054387
#
#               reads_per_million_miRNA_mapped_TCGA-YH-A8SY-01A-11R-A37H-13  \
# miRNA_ID
# hsa-let-7a-1                                       14862.937130
# hsa-let-7a-2                                       14798.404418
#
#               reads_per_million_miRNA_mapped_TCGA-2L-AAQJ-01A-12R-A39J-13  \
# miRNA_ID
# hsa-let-7a-1                                        9887.730083
# hsa-let-7a-2                                        9880.931195
#
#               reads_per_million_miRNA_mapped_TCGA-FB-AAPZ-01A-11R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                                        7526.564186
# hsa-let-7a-2                                        7520.665205
#
#               reads_per_million_miRNA_mapped_TCGA-IB-7646-01A-11R-2155-13
# miRNA_ID
# hsa-let-7a-1                                        8094.175726
# hsa-let-7a-2                                        8144.412376
#
# [2 rows x 183 columns]

# %% [markdown]
# Change column names

# %%
mirna_data.columns = mirna_data.columns.str.split('mapped_').str[1]

# %%
mirna_data.head(2)
# Out:
#               TCGA-3A-A9I7-01A-21R-A38N-13  TCGA-Z5-AAPL-01A-12R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                   8974.295034                   8188.083643
# hsa-let-7a-2                   8966.867080                   8120.177963
#
#               TCGA-H6-A45N-11A-12R-A26Y-13  TCGA-HZ-7922-01A-11R-2155-13  \
# miRNA_ID
# hsa-let-7a-1                   5924.427150                   9848.547177
# hsa-let-7a-2                   5991.516275                   9847.060305
#
#               TCGA-H6-A45N-01A-11R-A26Y-13  TCGA-IB-7645-01A-22R-2203-13  \
# miRNA_ID
# hsa-let-7a-1                   6504.359195                   8725.311259
# hsa-let-7a-2                   6549.357332                   8529.989984
#
#               TCGA-2J-AABF-01A-31R-A41G-13  TCGA-H6-8124-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                   8576.109395                  13959.663507
# hsa-let-7a-2                   8450.951735                  13919.584508
#
#               TCGA-FB-AAQ0-01A-31R-A41G-13  TCGA-HZ-A9TJ-01A-11R-A41D-13  ...  \
# miRNA_ID                                                                  ...
# hsa-let-7a-1                   7682.726535                   7299.262318  ...
# hsa-let-7a-2                   7672.791804                   7385.848430  ...
#
#               TCGA-HZ-A49H-01A-11R-A26Y-13  TCGA-Q3-A5QY-01A-12R-A32J-13  \
# miRNA_ID
# hsa-let-7a-1                   6063.950022                  13487.928421
# hsa-let-7a-2                   6052.934976                  13413.739287
#
#               TCGA-HZ-A4BH-01A-11R-A26Y-13  TCGA-2J-AAB8-01A-12R-A41G-13  \
# miRNA_ID
# hsa-let-7a-1                   6820.952950                   7090.095676
# hsa-let-7a-2                   6857.068316                   7092.906194
#
#               TCGA-3A-A9I9-01A-11R-A38N-13  TCGA-IB-8126-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                  10235.626935                   7929.784709
# hsa-let-7a-2                  10091.713697                   8027.054387
#
#               TCGA-YH-A8SY-01A-11R-A37H-13  TCGA-2L-AAQJ-01A-12R-A39J-13  \
# miRNA_ID
# hsa-let-7a-1                  14862.937130                   9887.730083
# hsa-let-7a-2                  14798.404418                   9880.931195
#
#               TCGA-FB-AAPZ-01A-11R-A41G-13  TCGA-IB-7646-01A-11R-2155-13
# miRNA_ID
# hsa-let-7a-1                   7526.564186                   8094.175726
# hsa-let-7a-2                   7520.665205                   8144.412376
#
# [2 rows x 183 columns]

# %% [markdown]
# Keep Only Primary Samples

# %%
mirna_data = mirna_data.filter(regex=r'^([^-]+-){3}01')

# %%
mirna_data.shape
# Out:
# (1881, 178)

# %% [markdown]
# Change column names TCGA-XX-XXXX-XXX-XXX-XXXX-XX to TCGA-XX-XXXX

# %%
mirna_data.columns = ['-'.join(col.split('-')[:3]) for col in mirna_data.columns]

# %%
mirna_data.head(2)
# Out:
#               TCGA-3A-A9I7  TCGA-Z5-AAPL  TCGA-HZ-7922  TCGA-H6-A45N  \
# miRNA_ID
# hsa-let-7a-1   8974.295034   8188.083643   9848.547177   6504.359195
# hsa-let-7a-2   8966.867080   8120.177963   9847.060305   6549.357332
#
#               TCGA-IB-7645  TCGA-2J-AABF  TCGA-H6-8124  TCGA-FB-AAQ0  \
# miRNA_ID
# hsa-let-7a-1   8725.311259   8576.109395  13959.663507   7682.726535
# hsa-let-7a-2   8529.989984   8450.951735  13919.584508   7672.791804
#
#               TCGA-HZ-A9TJ  TCGA-RB-AA9M  ...  TCGA-HZ-A49H  TCGA-Q3-A5QY  \
# miRNA_ID                                  ...
# hsa-let-7a-1   7299.262318  16863.509455  ...   6063.950022  13487.928421
# hsa-let-7a-2   7385.848430  16762.460854  ...   6052.934976  13413.739287
#
#               TCGA-HZ-A4BH  TCGA-2J-AAB8  TCGA-3A-A9I9  TCGA-IB-8126  \
# miRNA_ID
# hsa-let-7a-1   6820.952950   7090.095676  10235.626935   7929.784709
# hsa-let-7a-2   6857.068316   7092.906194  10091.713697   8027.054387
#
#               TCGA-YH-A8SY  TCGA-2L-AAQJ  TCGA-FB-AAPZ  TCGA-IB-7646
# miRNA_ID
# hsa-let-7a-1  14862.937130   9887.730083   7526.564186   8094.175726
# hsa-let-7a-2  14798.404418   9880.931195   7520.665205   8144.412376
#
# [2 rows x 178 columns]

# %% [markdown]
# Transpose to rows=samples, cols=features

# %%
mirna_data = mirna_data.T
mirna_data.head(2)
# Out:
# miRNA_ID      hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b  \
# TCGA-3A-A9I7   8974.295034   8966.867080   8912.749128  12043.101235
# TCGA-Z5-AAPL   8188.083643   8120.177963   8289.942163  17198.580520
#
# miRNA_ID       hsa-let-7c  hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# TCGA-3A-A9I7  1009.936480  334.788505  1081.828465   4338.190508
# TCGA-Z5-AAPL  1288.112063  733.968182   671.092552   2797.546341
#
# miRNA_ID      hsa-let-7f-2   hsa-let-7g  ...  hsa-mir-941-5  hsa-mir-942  \
# TCGA-3A-A9I7   4344.292042   730.592348  ...            0.0     2.122273
# TCGA-Z5-AAPL   2814.732347  1551.770536  ...            0.0    15.928493
#
# miRNA_ID      hsa-mir-943  hsa-mir-944  hsa-mir-95  hsa-mir-9500  hsa-mir-96  \
# TCGA-3A-A9I7          0.0     0.265284    3.713977           0.0   16.712897
# TCGA-Z5-AAPL          0.0     4.191709    6.706734           0.0   11.736784
#
# miRNA_ID      hsa-mir-98  hsa-mir-99a   hsa-mir-99b
# TCGA-3A-A9I7   41.914884   294.995893   9011.700089
# TCGA-Z5-AAPL   61.618117   527.316946  20213.257368
#
# [2 rows x 1881 columns]

# %% [markdown]
# Change index name

# %%
mirna_data.index.name = 'patient_id'
mirna_data.columns.name = None
mirna_data.head(3)
# Out:
#               hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b  \
# patient_id
# TCGA-3A-A9I7   8974.295034   8966.867080   8912.749128  12043.101235
# TCGA-Z5-AAPL   8188.083643   8120.177963   8289.942163  17198.580520
# TCGA-HZ-7922   9848.547177   9847.060305   9834.669701  34630.745151
#
#                hsa-let-7c  hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# patient_id
# TCGA-3A-A9I7  1009.936480  334.788505  1081.828465   4338.190508
# TCGA-Z5-AAPL  1288.112063  733.968182   671.092552   2797.546341
# TCGA-HZ-7922  2852.069082  545.434360  2182.480876   2237.247343
#
#               hsa-let-7f-2   hsa-let-7g  ...  hsa-mir-941-5  hsa-mir-942  \
# patient_id                               ...
# TCGA-3A-A9I7   4344.292042   730.592348  ...            0.0     2.122273
# TCGA-Z5-AAPL   2814.732347  1551.770536  ...            0.0    15.928493
# TCGA-HZ-7922   2254.346376   272.345462  ...            0.0     5.947490
#
#               hsa-mir-943  hsa-mir-944  hsa-mir-95  hsa-mir-9500  hsa-mir-96  \
# patient_id
# TCGA-3A-A9I7          0.0     0.265284    3.713977           0.0   16.712897
# TCGA-Z5-AAPL          0.0     4.191709    6.706734           0.0   11.736784
# TCGA-HZ-7922          0.0     0.743436   10.408107           0.0    2.230309
#
#               hsa-mir-98  hsa-mir-99a   hsa-mir-99b
# patient_id
# TCGA-3A-A9I7   41.914884   294.995893   9011.700089
# TCGA-Z5-AAPL   61.618117   527.316946  20213.257368
# TCGA-HZ-7922   32.463381   900.796864  52345.342967
#
# [3 rows x 1881 columns]

# %% [markdown]
# Remove duplicate patient samples

# %%
mirna_data = mirna_data[~mirna_data.index.duplicated(keep='first')]
mirna_data.shape
# Out:
# (178, 1881)

# %% [markdown]
# Remove duplicate miRNAs

# %%
mirna_data = mirna_data.loc[:, ~mirna_data.columns.duplicated(keep='first')]
mirna_data.shape
# Out:
# (178, 1881)

# %% [markdown]
# Count the total number of missing values in mirna_data

# %%
total_missing_mirna = mirna_data.isnull().sum().sum()
print(f"Total missing values in mirna_data: {total_missing_mirna}")
# Out:
# Total missing values in mirna_data: 0

# %%
mirna_data.shape
# Out:
# (178, 1881)

# %% [markdown]
# #### Target Gene Validation via MiRTarBase

# %% [markdown]
# Load MiRTarBase

# %%
mirtarbase = pd.read_csv('../../data/raw_data/hsa_MTI.csv')

# %%
mirtarbase.head(2)
# Out:
#   miRTarBase ID           miRNA Species (miRNA) Target Gene  \
# 0    MIRT003105  hsa-miR-122-5p             hsa      SLC7A1
# 1    MIRT003105  hsa-miR-122-5p             hsa      SLC7A1
#
#    Target Gene (Entrez ID) Species (Target Gene)  \
# 0                   6541.0                   hsa
# 1                   6541.0                   hsa
#
#                                Experiments        Support Type  \
# 0  Luciferase reporter assay//Western blot      Functional MTI
# 1  Luciferase reporter assay//Western blot  Non-Functional MTI
#
#    References (PMID)
# 0         17179747.0
# 1         17179747.0

# %% [markdown]
# Standardize miRNA names in mirtarbase

# %%
mirtarbase['miRNA'] = mirtarbase['miRNA'].astype(str).str.lower().str.split('-').str[:3].str.join('-')
mirtarbase.head(2)
# Out:
#   miRTarBase ID        miRNA Species (miRNA) Target Gene  \
# 0    MIRT003105  hsa-mir-122             hsa      SLC7A1
# 1    MIRT003105  hsa-mir-122             hsa      SLC7A1
#
#    Target Gene (Entrez ID) Species (Target Gene)  \
# 0                   6541.0                   hsa
# 1                   6541.0                   hsa
#
#                                Experiments        Support Type  \
# 0  Luciferase reporter assay//Western blot      Functional MTI
# 1  Luciferase reporter assay//Western blot  Non-Functional MTI
#
#    References (PMID)
# 0         17179747.0
# 1         17179747.0

# %%
mirna_data.head(2)
# Out:
#               hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3    hsa-let-7b  \
# patient_id
# TCGA-3A-A9I7   8974.295034   8966.867080   8912.749128  12043.101235
# TCGA-Z5-AAPL   8188.083643   8120.177963   8289.942163  17198.580520
#
#                hsa-let-7c  hsa-let-7d   hsa-let-7e  hsa-let-7f-1  \
# patient_id
# TCGA-3A-A9I7  1009.936480  334.788505  1081.828465   4338.190508
# TCGA-Z5-AAPL  1288.112063  733.968182   671.092552   2797.546341
#
#               hsa-let-7f-2   hsa-let-7g  ...  hsa-mir-941-5  hsa-mir-942  \
# patient_id                               ...
# TCGA-3A-A9I7   4344.292042   730.592348  ...            0.0     2.122273
# TCGA-Z5-AAPL   2814.732347  1551.770536  ...            0.0    15.928493
#
#               hsa-mir-943  hsa-mir-944  hsa-mir-95  hsa-mir-9500  hsa-mir-96  \
# patient_id
# TCGA-3A-A9I7          0.0     0.265284    3.713977           0.0   16.712897
# TCGA-Z5-AAPL          0.0     4.191709    6.706734           0.0   11.736784
#
#               hsa-mir-98  hsa-mir-99a   hsa-mir-99b
# patient_id
# TCGA-3A-A9I7   41.914884   294.995893   9011.700089
# TCGA-Z5-AAPL   61.618117   527.316946  20213.257368
#
# [2 rows x 1881 columns]

# %% [markdown]
# Filtering mirna_data

# %%
mirna_data.shape
# Out:
# (178, 1881)

# %%
mirtarbase_mirnas = set(mirtarbase['miRNA'])
columns_to_keep = [col for col in mirna_data.columns if '-'.join(col.split('-')[:3]) in mirtarbase_mirnas]
mirna_data = mirna_data[columns_to_keep]

# %%
mirna_data.shape
# Out:
# (178, 1881)

# %% [markdown]
# ################

# %% [markdown]
# Create a list with mirna_data column names

# %%
mirna_columns = mirna_data.columns.tolist()

# %%
print(mirna_columns[:5])
# Out:
# ['hsa-let-7a-1', 'hsa-let-7a-2', 'hsa-let-7a-3', 'hsa-let-7b', 'hsa-let-7c']

# %% [markdown]
# Standardize miRNA names

# %%
mirna_columns = ['-'.join(col.split('-')[:3]) for col in mirna_columns]
print(mirna_columns[:5])
# Out:
# ['hsa-let-7a', 'hsa-let-7a', 'hsa-let-7a', 'hsa-let-7b', 'hsa-let-7c']

# %%
print(len(mirna_columns))
# Out:
# 1881

# %% [markdown]
# Remove Duplicates

# %%
mirna_columns = list(set(mirna_columns))
print(len(mirna_columns))
# Out:
# 1704

# %% [markdown]
# mirna_data columns present in mirtarbase[‘miRNA’]

# %%
matching_mirnas = set(mirna_columns) & set(mirtarbase['miRNA'])
print(f"Number of matching miRNAs: {len(matching_mirnas)}")
# Out:
# Number of matching miRNAs: 1704

# %% [markdown]
# ################

# %% [markdown]
# ### DNA Methylation Preprocessing

# %%
meth_data.head(2)
# Out:
#    Unnamed: 0  TCGA-2J-AABR-01A-11D-A40Y-05  TCGA-FB-AAPS-01A-12D-A398-05  \
# 0  cg13869341                           NaN                           NaN
# 1  cg14008030                           NaN                           NaN
#
#    TCGA-IB-AAUO-01A-12D-A38H-05  TCGA-IB-AAUN-01A-12D-A38H-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-RB-A7B8-01A-12D-A33U-05  TCGA-IB-7885-01A-11D-2157-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-IB-AAUW-01A-12D-A38H-05  TCGA-FZ-5919-11A-02D-1744-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-IB-A5ST-01A-11D-A32S-05  ...  TCGA-HV-A5A5-01A-11D-A26Q-05  \
# 0                           NaN  ...                           NaN
# 1                           NaN  ...                           NaN
#
#    TCGA-HZ-A49I-01A-12D-A26Q-05  TCGA-Q3-A5QY-01A-12D-A32S-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-2J-AABT-01A-11D-A40Y-05  TCGA-FB-A5VM-01A-11D-A32S-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-FZ-5924-01A-13D-1744-05  TCGA-IB-7890-01A-12D-2202-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-2L-AAQJ-01A-12D-A398-05  TCGA-HZ-A77O-01A-11D-A33U-05  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    TCGA-FB-AAQ2-01A-31D-A40Y-05
# 0                           NaN
# 1                           NaN
#
# [2 rows x 196 columns]

# %%
meth_data.set_index('Unnamed: 0', inplace=True)

# %%
meth_data.head(2)
# Out:
#             TCGA-2J-AABR-01A-11D-A40Y-05  TCGA-FB-AAPS-01A-12D-A398-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-IB-AAUO-01A-12D-A38H-05  TCGA-IB-AAUN-01A-12D-A38H-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-RB-A7B8-01A-12D-A33U-05  TCGA-IB-7885-01A-11D-2157-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-IB-AAUW-01A-12D-A38H-05  TCGA-FZ-5919-11A-02D-1744-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-IB-A5ST-01A-11D-A32S-05  TCGA-IB-A7LX-01A-12D-A368-05  ...  \
# Unnamed: 0                                                              ...
# cg13869341                           NaN                           NaN  ...
# cg14008030                           NaN                           NaN  ...
#
#             TCGA-HV-A5A5-01A-11D-A26Q-05  TCGA-HZ-A49I-01A-12D-A26Q-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-Q3-A5QY-01A-12D-A32S-05  TCGA-2J-AABT-01A-11D-A40Y-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-FB-A5VM-01A-11D-A32S-05  TCGA-FZ-5924-01A-13D-1744-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-IB-7890-01A-12D-2202-05  TCGA-2L-AAQJ-01A-12D-A398-05  \
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
#             TCGA-HZ-A77O-01A-11D-A33U-05  TCGA-FB-AAQ2-01A-31D-A40Y-05
# Unnamed: 0
# cg13869341                           NaN                           NaN
# cg14008030                           NaN                           NaN
#
# [2 rows x 195 columns]

# %% [markdown]
# Keep Only Primary Samples

# %%
meth_data = meth_data.filter(regex=r'^([^-]+-){3}01')

# %%
meth_data.shape
# Out:
# (485577, 184)

# %% [markdown]
# Change column names TCGA-XX-XXXX-XXX-XXX-XXXX-XX to TCGA-XX-XXXX

# %%
meth_data.columns = ['-'.join(col.split('-')[:3]) for col in meth_data.columns]

# %%
meth_data.head(2)
# Out:
#             TCGA-2J-AABR  TCGA-FB-AAPS  TCGA-IB-AAUO  TCGA-IB-AAUN  \
# Unnamed: 0
# cg13869341           NaN           NaN           NaN           NaN
# cg14008030           NaN           NaN           NaN           NaN
#
#             TCGA-RB-A7B8  TCGA-IB-7885  TCGA-IB-AAUW  TCGA-IB-A5ST  \
# Unnamed: 0
# cg13869341           NaN           NaN           NaN           NaN
# cg14008030           NaN           NaN           NaN           NaN
#
#             TCGA-IB-A7LX  TCGA-FB-AAQ3  ...  TCGA-HV-A5A5  TCGA-HZ-A49I  \
# Unnamed: 0                              ...
# cg13869341           NaN           NaN  ...           NaN           NaN
# cg14008030           NaN           NaN  ...           NaN           NaN
#
#             TCGA-Q3-A5QY  TCGA-2J-AABT  TCGA-FB-A5VM  TCGA-FZ-5924  \
# Unnamed: 0
# cg13869341           NaN           NaN           NaN           NaN
# cg14008030           NaN           NaN           NaN           NaN
#
#             TCGA-IB-7890  TCGA-2L-AAQJ  TCGA-HZ-A77O  TCGA-FB-AAQ2
# Unnamed: 0
# cg13869341           NaN           NaN           NaN           NaN
# cg14008030           NaN           NaN           NaN           NaN
#
# [2 rows x 184 columns]

# %% [markdown]
# Transpose to rows=samples, cols=features

# %%
meth_data = meth_data.T
meth_data.head(2)
# Out:
# Unnamed: 0    cg13869341  cg14008030  cg12045430  cg20826792  cg00381604  \
# TCGA-2J-AABR         NaN         NaN         NaN         NaN         NaN
# TCGA-FB-AAPS         NaN         NaN         NaN         NaN         NaN
#
# Unnamed: 0    cg20253340  cg21870274  cg03130891  cg24335620  cg16162899  ...  \
# TCGA-2J-AABR         NaN    0.821993         NaN         NaN         NaN  ...
# TCGA-FB-AAPS         NaN    0.770366         NaN         NaN         NaN  ...
#
# Unnamed: 0    cg25005368  cg02953382  cg01238044  cg01957799  cg20064778  \
# TCGA-2J-AABR         NaN         NaN         NaN         NaN         NaN
# TCGA-FB-AAPS         NaN         NaN         NaN         NaN         NaN
#
# Unnamed: 0    cg24238852  cg15254640  cg24336839  cg11478607  cg08417382
# TCGA-2J-AABR         NaN         NaN         NaN         NaN         NaN
# TCGA-FB-AAPS         NaN         NaN         NaN         NaN         NaN
#
# [2 rows x 485577 columns]

# %% [markdown]
# Change index name

# %%
meth_data.index.name = 'patient_id'
meth_data.columns.name = None
meth_data.head(2)
# Out:
#               cg13869341  cg14008030  cg12045430  cg20826792  cg00381604  \
# patient_id
# TCGA-2J-AABR         NaN         NaN         NaN         NaN         NaN
# TCGA-FB-AAPS         NaN         NaN         NaN         NaN         NaN
#
#               cg20253340  cg21870274  cg03130891  cg24335620  cg16162899  ...  \
# patient_id                                                                ...
# TCGA-2J-AABR         NaN    0.821993         NaN         NaN         NaN  ...
# TCGA-FB-AAPS         NaN    0.770366         NaN         NaN         NaN  ...
#
#               cg25005368  cg02953382  cg01238044  cg01957799  cg20064778  \
# patient_id
# TCGA-2J-AABR         NaN         NaN         NaN         NaN         NaN
# TCGA-FB-AAPS         NaN         NaN         NaN         NaN         NaN
#
#               cg24238852  cg15254640  cg24336839  cg11478607  cg08417382
# patient_id
# TCGA-2J-AABR         NaN         NaN         NaN         NaN         NaN
# TCGA-FB-AAPS         NaN         NaN         NaN         NaN         NaN
#
# [2 rows x 485577 columns]

# %% [markdown]
# Remove duplicate patient samples

# %%
meth_data = meth_data[~meth_data.index.duplicated(keep='first')]
meth_data.shape
# Out:
# (184, 485577)

# %% [markdown]
# Remove duplicate Cpgs

# %%
meth_data = meth_data.loc[:, ~meth_data.columns.duplicated(keep='first')]
meth_data.shape
# Out:
# (184, 485577)

# %% [markdown]
# Keep only columns that start with 'cg' (CpG probes)

# %%
meth_data = meth_data.filter(regex='^cg')
meth_data.shape
# Out:
# (184, 482421)

# %% [markdown]
# Remove CpG sites located on sex chromosomes

# %%
xy_probes = pd.read_csv('../../data/annotations/meth_ChrXY_probes.csv')

# %%
print(meth_data.shape)
print(xy_probes.shape)
# Out:
# (184, 482421)
# (11648, 1)

# %%
xy_probes.head(2)
# Out:
#         Probe
# 0  cg00050873
# 1  cg00212031

# %%
xy_probes['Probe'] = xy_probes['Probe'].astype(str).tolist()
meth_data.columns = meth_data.columns.astype(str)
meth_data = meth_data.loc[:, ~meth_data.columns.isin(xy_probes['Probe'])]
meth_data.shape
# Out:
# (184, 470870)

# %% [markdown]
# Remove CpG sites overlapping known SNPs

# %%
snp_probes = pd.read_csv('../../data/annotations/meth_SNP_probes.csv')

# %%
print(meth_data.shape)
print(snp_probes.shape)
# Out:
# (184, 470870)
# (104016, 1)

# %%
snp_probes.head(2)
# Out:
#         Probe
# 0  cg00072288
# 1  cg00374088

# %%
snp_probes['Probe'] = snp_probes['Probe'].astype(str).tolist()
meth_data = meth_data.loc[:, ~meth_data.columns.isin(snp_probes['Probe'])]
meth_data.shape
# Out:
# (184, 368548)

# %% [markdown]
# Remove cross-reactive CpG probes

# %%
cross_reactive_probes = pd.read_csv('../../data/annotations/meth_cross_reactive_probes.csv')

# %%
print(meth_data.shape)
print(cross_reactive_probes.shape)
# Out:
# (184, 368548)
# (9341, 38)

# %%
cross_reactive_probes.head(2)
# Out:
#   Probe.TargetID Probe.INFINIUM_DESIGN_TYPE  Probe.GENOME_BUILD  Probe.CHR  \
# 0     cg00001510                          I                  37         19
# 1     cg00003969                         II                  37         15
#
#    Probe.MAPINFO Probe.CHROMOSOME_36 Probe.COORDINATE_36 Probe.STRAND  \
# 0       54746945                  19            59438757            R
# 1       82925333                  15            80722388            F
#
#   Probe.UCSC_REFGENE_NAME Probe.UCSC_REFGENE_ACCESSION  ... Probe.dmc.T  \
# 0                  LILRA6                    NM_024318  ...         NaN
# 1                     NaN                          NaN  ...         NaN
#
#   Probe.dmc.MLL Probe.dmc.dic920 Probe.dmc.HeH Probe.dmc.t119  \
# 0           NaN              NaN           NaN            NaN
# 1           NaN              NaN           NaN            NaN
#
#    Probe.dmc.t1221  Probe.dmc.t922  Probe.dmc.iamp  Probe.dmc.undefined  \
# 0              NaN             NaN             NaN                  NaN
# 1              NaN             NaN             NaN                  NaN
#
#    Probe.dmc.nonrecurrent
# 0                     NaN
# 1                     NaN
#
# [2 rows x 38 columns]

# %%
cross_reactive_probes['Probe.TargetID'] = cross_reactive_probes['Probe.TargetID'].astype(str).tolist()
meth_data = meth_data.loc[:, ~meth_data.columns.isin(cross_reactive_probes['Probe.TargetID'])]
meth_data.shape
# Out:
# (184, 362570)

# %% [markdown]
# #### Map CpG sites to mRNA genes

# %%
mapping_probes = pd.read_csv('../../data/annotations/illumina_mapping.csv')

# %%
mapping_probes.head(10)
# Out:
#           CpG               Gene
# 0  cg00050873     TSPY4;FAM197Y2
# 1  cg00212031             TTTY14
# 2  cg00213748                NaN
# 3  cg00214611      TMSB4Y;TMSB4Y
# 4  cg00455876                NaN
# 5  cg01707559  TBL1Y;TBL1Y;TBL1Y
# 6  cg02004872      TMSB4Y;TMSB4Y
# 7  cg02011394              TSPY4
# 8  cg02050847      RPS4Y2;RPS4Y2
# 9  cg02233190             EIF1AY

# %%
mapping_probes.shape
# Out:
# (485512, 2)

# %%
mapping_probes = mapping_probes.dropna(subset=['Gene'])
mapping_probes.shape
# Out:
# (365860, 2)

# %%
mapping_probes['Gene'] = mapping_probes['Gene'].str.split(';')
mapping_probes = mapping_probes.explode('Gene')
mapping_probes.shape
# Out:
# (687137, 2)

# %% [markdown]
# Count duplicate rows

# %%
duplicated_map = mapping_probes[mapping_probes.duplicated(subset=['CpG', 'Gene'], keep=False)].sort_values(['CpG', 'Gene'])

# %%
duplicated_map.head(10)
# Out:
#                CpG     Gene
# 203755  cg00000108  C3orf35
# 203755  cg00000108  C3orf35
# 203756  cg00000109   FNDC3B
# 203756  cg00000109   FNDC3B
# 304062  cg00000236    VDAC3
# 304062  cg00000236    VDAC3
# 392121  cg00000289    ACTN1
# 392121  cg00000289    ACTN1
# 392121  cg00000289    ACTN1
# 414412  cg00000292   ATP2A1

# %%
duplicated_map.shape
# Out:
# (429567, 2)

# %%
duplicated_map = duplicated_map.drop_duplicates(subset=['CpG', 'Gene'], keep='first')
duplicated_map.shape
# Out:
# (149520, 2)

# %%
duplicated_map.head(10)
# Out:
#                CpG     Gene
# 203755  cg00000108  C3orf35
# 203756  cg00000109   FNDC3B
# 304062  cg00000236    VDAC3
# 392121  cg00000289    ACTN1
# 414412  cg00000292   ATP2A1
# 98155   cg00000622    NIPA2
# 452525  cg00000714   TSEN34
# 203757  cg00000734     CNBP
# 345013  cg00000924    KCNQ1
# 25036   cg00001245   MRPS25

# %% [markdown]
# Map CpGs to mRNAs from mrna_data

# %%
genes_mrna_data = gene_annotation['gene_name'].unique()
valid_cpgs = mapping_probes[mapping_probes['Gene'].isin(genes_mrna_data)]['CpG'].unique()

# %%
meth_data.shape
# Out:
# (184, 362570)

# %%
meth_data = meth_data.loc[:, meth_data.columns.isin(valid_cpgs)]
meth_data.shape
# Out:
# (184, 247142)

# %% [markdown]
# Delete features with more than 10% of missing values

# %%
meth_data = meth_data.loc[:, meth_data.isnull().mean() <= 0.1]
meth_data.shape
# Out:
# (184, 221628)

# %% [markdown]
# #### Intersect common patients across omics

# %% [markdown]
# Common patients

# %%
common_patients = set(mrna_data.index) & set(mirna_data.index) & set(meth_data.index)
len(common_patients)
# Out:
# 178

# %% [markdown]
# Filter datasets to keep only patients in common

# %%
mrna_data = mrna_data.loc[mrna_data.index.isin(common_patients)]
mirna_data = mirna_data.loc[mirna_data.index.isin(common_patients)]
meth_data = meth_data.loc[meth_data.index.isin(common_patients)]

# %%
print(mrna_data.shape)
print(mirna_data.shape)
print(meth_data.shape)
# Out:
# (178, 60616)
# (178, 1881)
# (178, 221628)

# %% [markdown]
# ### Clinical Data

# %%
clinical_data.head(4)
# Out:
#                        bcr_patient_uuid  bcr_patient_barcode  \
# 0                      bcr_patient_uuid  bcr_patient_barcode
# 1                               CDE_ID:       CDE_ID:2003301
# 2  75119D1A-93E5-4AE7-9D60-69EE929A0772         TCGA-2J-AAB1
# 3  33833131-1482-42D5-9CF5-01CADE540234         TCGA-2J-AAB4
#
#    form_completion_date invasive_adenocarcinoma_indicator  \
# 0  form_completion_date           adenocarcinoma_invasion
# 1               CDE_ID:                    CDE_ID:3027106
# 2             2014-7-16                               YES
# 3             2014-7-16                               YES
#
#                     histologic_diagnosis     histologic_diagnosis_other  \
# 0                      histological_type        histological_type_other
# 1                         CDE_ID:3081934                 CDE_ID:3124492
# 2  Pancreas-Adenocarcinoma-Other Subtype        invasive adenocarcinoma
# 3  Pancreas-Adenocarcinoma-Other Subtype  invasive, well-differentiated
#
#   tumor_sample_type                   prospective_collection  \
# 0        tumor_type  tissue_prospective_collection_indicator
# 1    CDE_ID:3288124                           CDE_ID:3088492
# 2           Primary                                       NO
# 3           Primary                                       NO
#
#                     retrospective_collection          gender  ...  \
# 0  tissue_retrospective_collection_indicator          gender  ...
# 1                             CDE_ID:3088528  CDE_ID:2200604  ...
# 2                                        YES            MALE  ...
# 3                                        YES            MALE  ...
#
#    extranodal_involvement          icd_10  icd_o_3_histology    icd_o_3_site  \
# 0  extranodal_involvement          icd_10  icd_o_3_histology    icd_o_3_site
# 1          CDE_ID:3364582  CDE_ID:3226287     CDE_ID:3226275  CDE_ID:3226281
# 2        [Not Applicable]           C25.0             8480/3           C25.0
# 3        [Not Applicable]           C25.8             8140/3           C25.8
#
#    informed_consent_verified  patient_id     project_code      stage_other  \
# 0  informed_consent_verified  patient_id     project_code      stage_other
# 1             CDE_ID:3288361     CDE_ID:          CDE_ID:   CDE_ID:2007104
# 2                        YES        AAB1  [Not Available]  [Not Available]
# 3                        YES        AAB4  [Not Available]  [Not Available]
#
#    tissue_source_site  tumor_tissue_site
# 0  tissue_source_site  tumor_tissue_site
# 1             CDE_ID:     CDE_ID:3427536
# 2                  2J           Pancreas
# 3                  2J           Pancreas
#
# [4 rows x 77 columns]

# %%
clinical_data = clinical_data.drop([0, 1])

# %%
clinical_data.head(3)
# Out:
#                        bcr_patient_uuid bcr_patient_barcode  \
# 2  75119D1A-93E5-4AE7-9D60-69EE929A0772        TCGA-2J-AAB1
# 3  33833131-1482-42D5-9CF5-01CADE540234        TCGA-2J-AAB4
# 4  70797499-16E6-48CC-8AE4-1E692713DAD3        TCGA-2J-AAB6
#
#   form_completion_date invasive_adenocarcinoma_indicator  \
# 2            2014-7-16                               YES
# 3            2014-7-16                               YES
# 4            2014-7-16                               YES
#
#                     histologic_diagnosis     histologic_diagnosis_other  \
# 2  Pancreas-Adenocarcinoma-Other Subtype        invasive adenocarcinoma
# 3  Pancreas-Adenocarcinoma-Other Subtype  invasive, well-differentiated
# 4    Pancreas-Adenocarcinoma Ductal Type               [Not Applicable]
#
#   tumor_sample_type prospective_collection retrospective_collection gender  \
# 2           Primary                     NO                      YES   MALE
# 3           Primary                     NO                      YES   MALE
# 4           Primary                     NO                      YES   MALE
#
#    ... extranodal_involvement icd_10 icd_o_3_histology icd_o_3_site  \
# 2  ...       [Not Applicable]  C25.0            8480/3        C25.0
# 3  ...       [Not Applicable]  C25.8            8140/3        C25.8
# 4  ...       [Not Applicable]  C25.1            8500/3        C25.1
#
#   informed_consent_verified patient_id     project_code      stage_other  \
# 2                       YES       AAB1  [Not Available]  [Not Available]
# 3                       YES       AAB4  [Not Available]  [Not Available]
# 4                       YES       AAB6  [Not Available]  [Not Available]
#
#   tissue_source_site tumor_tissue_site
# 2                 2J          Pancreas
# 3                 2J          Pancreas
# 4                 2J          Pancreas
#
# [3 rows x 77 columns]

# %% [markdown]
# Set bcr_patient_barcode to index

# %%
clinical_data.set_index('bcr_patient_barcode', inplace=True)

# %%
clinical_data.index.name = 'patient_id'
clinical_data.head(3)
# Out:
#                                   bcr_patient_uuid form_completion_date  \
# patient_id
# TCGA-2J-AAB1  75119D1A-93E5-4AE7-9D60-69EE929A0772            2014-7-16
# TCGA-2J-AAB4  33833131-1482-42D5-9CF5-01CADE540234            2014-7-16
# TCGA-2J-AAB6  70797499-16E6-48CC-8AE4-1E692713DAD3            2014-7-16
#
#              invasive_adenocarcinoma_indicator  \
# patient_id
# TCGA-2J-AAB1                               YES
# TCGA-2J-AAB4                               YES
# TCGA-2J-AAB6                               YES
#
#                                histologic_diagnosis  \
# patient_id
# TCGA-2J-AAB1  Pancreas-Adenocarcinoma-Other Subtype
# TCGA-2J-AAB4  Pancreas-Adenocarcinoma-Other Subtype
# TCGA-2J-AAB6    Pancreas-Adenocarcinoma Ductal Type
#
#                  histologic_diagnosis_other tumor_sample_type  \
# patient_id
# TCGA-2J-AAB1        invasive adenocarcinoma           Primary
# TCGA-2J-AAB4  invasive, well-differentiated           Primary
# TCGA-2J-AAB6               [Not Applicable]           Primary
#
#              prospective_collection retrospective_collection gender  \
# patient_id
# TCGA-2J-AAB1                     NO                      YES   MALE
# TCGA-2J-AAB4                     NO                      YES   MALE
# TCGA-2J-AAB6                     NO                      YES   MALE
#
#              birth_days_to  ... extranodal_involvement icd_10  \
# patient_id                  ...
# TCGA-2J-AAB1        -23962  ...       [Not Applicable]  C25.0
# TCGA-2J-AAB4        -17794  ...       [Not Applicable]  C25.8
# TCGA-2J-AAB6        -27600  ...       [Not Applicable]  C25.1
#
#              icd_o_3_histology icd_o_3_site informed_consent_verified  \
# patient_id
# TCGA-2J-AAB1            8480/3        C25.0                       YES
# TCGA-2J-AAB4            8140/3        C25.8                       YES
# TCGA-2J-AAB6            8500/3        C25.1                       YES
#
#              patient_id     project_code      stage_other tissue_source_site  \
# patient_id
# TCGA-2J-AAB1       AAB1  [Not Available]  [Not Available]                 2J
# TCGA-2J-AAB4       AAB4  [Not Available]  [Not Available]                 2J
# TCGA-2J-AAB6       AAB6  [Not Available]  [Not Available]                 2J
#
#              tumor_tissue_site
# patient_id
# TCGA-2J-AAB1          Pancreas
# TCGA-2J-AAB4          Pancreas
# TCGA-2J-AAB6          Pancreas
#
# [3 rows x 76 columns]

# %%
clinical_data.shape
# Out:
# (185, 76)

# %% [markdown]
# Keep the same patients from the omics datasets

# %%
clinical_data = clinical_data.loc[clinical_data.index.isin(common_patients)]
clinical_data.shape
# Out:
# (178, 76)

# %% [markdown]
# #### Constructing Target Variable

# %%
clinical_data['histologic_diagnosis'].value_counts()
# Out:
# histologic_diagnosis
# Pancreas-Adenocarcinoma Ductal Type                 147
# Pancreas-Adenocarcinoma-Other Subtype                25
# Pancreas-Colloid (mucinous non-cystic) Carcinoma      4
# Pancreas-Undifferentiated Carcinoma                   1
# [Discrepancy]                                         1
# Name: count, dtype: int64

# %% [markdown]
# Remove patients with Pancreas-Undifferentiated Carcinoma and [Discrepancy]

# %%
clinical_data_rows_to_remove = clinical_data['histologic_diagnosis'].isin(['Pancreas-Undifferentiated Carcinoma', '[Discrepancy]'])

# %%
clinical_data = clinical_data.loc[~clinical_data_rows_to_remove]
clinical_data.shape
# Out:
# (176, 76)

# %% [markdown]
# Create feature tumor_subtype

# %%
clinical_data.head(3)
# Out:
#                                   bcr_patient_uuid form_completion_date  \
# patient_id
# TCGA-2J-AAB1  75119D1A-93E5-4AE7-9D60-69EE929A0772            2014-7-16
# TCGA-2J-AAB4  33833131-1482-42D5-9CF5-01CADE540234            2014-7-16
# TCGA-2J-AAB6  70797499-16E6-48CC-8AE4-1E692713DAD3            2014-7-16
#
#              invasive_adenocarcinoma_indicator  \
# patient_id
# TCGA-2J-AAB1                               YES
# TCGA-2J-AAB4                               YES
# TCGA-2J-AAB6                               YES
#
#                                histologic_diagnosis  \
# patient_id
# TCGA-2J-AAB1  Pancreas-Adenocarcinoma-Other Subtype
# TCGA-2J-AAB4  Pancreas-Adenocarcinoma-Other Subtype
# TCGA-2J-AAB6    Pancreas-Adenocarcinoma Ductal Type
#
#                  histologic_diagnosis_other tumor_sample_type  \
# patient_id
# TCGA-2J-AAB1        invasive adenocarcinoma           Primary
# TCGA-2J-AAB4  invasive, well-differentiated           Primary
# TCGA-2J-AAB6               [Not Applicable]           Primary
#
#              prospective_collection retrospective_collection gender  \
# patient_id
# TCGA-2J-AAB1                     NO                      YES   MALE
# TCGA-2J-AAB4                     NO                      YES   MALE
# TCGA-2J-AAB6                     NO                      YES   MALE
#
#              birth_days_to  ... extranodal_involvement icd_10  \
# patient_id                  ...
# TCGA-2J-AAB1        -23962  ...       [Not Applicable]  C25.0
# TCGA-2J-AAB4        -17794  ...       [Not Applicable]  C25.8
# TCGA-2J-AAB6        -27600  ...       [Not Applicable]  C25.1
#
#              icd_o_3_histology icd_o_3_site informed_consent_verified  \
# patient_id
# TCGA-2J-AAB1            8480/3        C25.0                       YES
# TCGA-2J-AAB4            8140/3        C25.8                       YES
# TCGA-2J-AAB6            8500/3        C25.1                       YES
#
#              patient_id     project_code      stage_other tissue_source_site  \
# patient_id
# TCGA-2J-AAB1       AAB1  [Not Available]  [Not Available]                 2J
# TCGA-2J-AAB4       AAB4  [Not Available]  [Not Available]                 2J
# TCGA-2J-AAB6       AAB6  [Not Available]  [Not Available]                 2J
#
#              tumor_tissue_site
# patient_id
# TCGA-2J-AAB1          Pancreas
# TCGA-2J-AAB4          Pancreas
# TCGA-2J-AAB6          Pancreas
#
# [3 rows x 76 columns]

# %%
clinical_data['tumor_subtype'] = np.where(clinical_data['histologic_diagnosis'].str.contains('Pancreas-Adenocarcinoma Ductal Type', case=False, na=False), 'ductal_type', 'other_subtype')

# %%
clinical_data.head(3)
# Out:
#                                   bcr_patient_uuid form_completion_date  \
# patient_id
# TCGA-2J-AAB1  75119D1A-93E5-4AE7-9D60-69EE929A0772            2014-7-16
# TCGA-2J-AAB4  33833131-1482-42D5-9CF5-01CADE540234            2014-7-16
# TCGA-2J-AAB6  70797499-16E6-48CC-8AE4-1E692713DAD3            2014-7-16
#
#              invasive_adenocarcinoma_indicator  \
# patient_id
# TCGA-2J-AAB1                               YES
# TCGA-2J-AAB4                               YES
# TCGA-2J-AAB6                               YES
#
#                                histologic_diagnosis  \
# patient_id
# TCGA-2J-AAB1  Pancreas-Adenocarcinoma-Other Subtype
# TCGA-2J-AAB4  Pancreas-Adenocarcinoma-Other Subtype
# TCGA-2J-AAB6    Pancreas-Adenocarcinoma Ductal Type
#
#                  histologic_diagnosis_other tumor_sample_type  \
# patient_id
# TCGA-2J-AAB1        invasive adenocarcinoma           Primary
# TCGA-2J-AAB4  invasive, well-differentiated           Primary
# TCGA-2J-AAB6               [Not Applicable]           Primary
#
#              prospective_collection retrospective_collection gender  \
# patient_id
# TCGA-2J-AAB1                     NO                      YES   MALE
# TCGA-2J-AAB4                     NO                      YES   MALE
# TCGA-2J-AAB6                     NO                      YES   MALE
#
#              birth_days_to  ... icd_10 icd_o_3_histology icd_o_3_site  \
# patient_id                  ...
# TCGA-2J-AAB1        -23962  ...  C25.0            8480/3        C25.0
# TCGA-2J-AAB4        -17794  ...  C25.8            8140/3        C25.8
# TCGA-2J-AAB6        -27600  ...  C25.1            8500/3        C25.1
#
#              informed_consent_verified patient_id     project_code  \
# patient_id
# TCGA-2J-AAB1                       YES       AAB1  [Not Available]
# TCGA-2J-AAB4                       YES       AAB4  [Not Available]
# TCGA-2J-AAB6                       YES       AAB6  [Not Available]
#
#                   stage_other tissue_source_site tumor_tissue_site  \
# patient_id
# TCGA-2J-AAB1  [Not Available]                 2J          Pancreas
# TCGA-2J-AAB4  [Not Available]                 2J          Pancreas
# TCGA-2J-AAB6  [Not Available]                 2J          Pancreas
#
#               tumor_subtype
# patient_id
# TCGA-2J-AAB1  other_subtype
# TCGA-2J-AAB4  other_subtype
# TCGA-2J-AAB6    ductal_type
#
# [3 rows x 77 columns]

# %%
clinical_data['tumor_subtype'].value_counts()
# Out:
# tumor_subtype
# ductal_type      147
# other_subtype     29
# Name: count, dtype: int64

# %% [markdown]
# Remove the two outliers from omics datasets

# %%
valid_patients = clinical_data.index

# %%
mrna_data = mrna_data.loc[mrna_data.index.isin(valid_patients)]
mirna_data = mirna_data.loc[mirna_data.index.isin(valid_patients)]
meth_data = meth_data.loc[meth_data.index.isin(valid_patients)]

# %%
print(mrna_data.shape)
print(mirna_data.shape)
print(meth_data.shape)
print(clinical_data.shape)
# Out:
# (176, 60616)
# (176, 1881)
# (176, 221628)
# (176, 77)

# %% [markdown]
# ############################

# %% [markdown]
# Ensure data is numeric and non-negative

# %%
#mrna
mrna_data = mrna_data.apply(pd.to_numeric, errors='coerce')
mrna_nans = mrna_data.isnull().sum().sum()
print(mrna_nans)

min_value_mrna = mrna_data.min().min()
print(min_value_mrna)

#mirna
mirna_data = mirna_data.apply(pd.to_numeric, errors='coerce')
mirna_nans = mirna_data.isnull().sum().sum()
print(mirna_nans)

min_value_mirna = mirna_data.min().min()
print(min_value_mirna)

#dna methylation
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
meth_nans = meth_data.isnull().sum().sum()
print(meth_nans)

min_value_meth = meth_data.min().min()
print(min_value_meth)
# Out:
# 0
# 0.0
# 0
# 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31712\1418007039.py in ?()
#      14 min_value_mirna = mirna_data.min().min()
#      15 print(min_value_mirna)
#      16
#      17 #dna methylation
# ---> 18 meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
#      19 meth_nans = meth_data.isnull().sum().sum()
#      20 print(meth_nans)
#      21
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10397             engine_kwargs=engine_kwargs,
#   10398             args=args,
#   10399             kwargs=kwargs,
#   10400         )
# > 10401         return op.apply().__finalize__(self, method="apply")
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\apply.py in ?(self)
#     912         # raw
#     913         elif self.raw:
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\apply.py in ?(self)
#    1061     def apply_standard(self):
#    1062         if self.engine == "python":
# -> 1063             results, res_index = self.apply_series_generator()
#    1064         else:
#    1065             results, res_index = self.apply_series_numba()
#    1066
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\apply.py in ?(self)
#    1075
#    1076         results = {}
#    1077
#    1078         with option_context("mode.chained_assignment", None):
# -> 1079             for i, v in enumerate(series_gen):
#    1080                 # ignore SettingWithCopy here in case the user mutates
#    1081                 results[i] = self.func(v, *self.args, **self.kwargs)
#    1082                 if isinstance(results[i], ABCSeries):
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\apply.py in ?(.0)
# -> 1139     def series_generator(self) -> Generator[Series, None, None]:
#    1140         return (self.obj._ixs(i, axis=1) for i in range(len(self.columns)))
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\frame.py in ?(self, i, axis)
#    4018         else:
#    4019             label = self.columns[i]
#    4020
#    4021             col_mgr = self._mgr.iget(i)
# -> 4022             result = self._box_col_values(col_mgr, i)
#    4023
#    4024             # this is a cached value, mark it so
#    4025             result._set_as_cached(label, self)
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\frame.py in ?(self, values, loc)
#    4625         name = self.columns[loc]
#    4626         # We get index=self.index bc values is a SingleDataManager
#    4627         obj = self._constructor_sliced_from_mgr(values, axes=values.axes)
#    4628         obj._name = name
# -> 4629         return obj.__finalize__(self)
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\generic.py in ?(self, other, method, **kwargs)
#    6280                 # One could make the deepcopy unconditionally, but a deepcopy
#    6281                 # of an empty dict is 50x more expensive than the empty check.
#    6282                 self.attrs = deepcopy(other.attrs)
#    6283
# -> 6284             self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    6285             # For subclasses using _metadata.
#    6286             for name in set(self._metadata) & set(other._metadata):
#    6287                 assert isinstance(name, str)
#
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\pandas\core\generic.py in ?(self)
# --> 408     @final
#     409     @property
#     410     def flags(self) -> Flags:
#     411         """
#
# KeyboardInterrupt:

# %% [markdown]
# ### mRNA and miRNA: Filtering variables with near-zero variance

# %% [markdown]
# Function to mimic R nearZeroVar() function

# %%
def near_zero_var(df, freq_cut=19.0, unique_cut=10.0):

    nzv_cols = []
    n_samples = len(df)
    
    for col in df.columns:

        value_counts = df[col].value_counts()
        num_unique = len(value_counts)

        if num_unique <= 1:
            nzv_cols.append(col)
            continue
            
        percent_unique = (num_unique / n_samples) * 100

        freq_ratio = value_counts.iloc[0] / value_counts.iloc[1]

        if (freq_ratio > freq_cut) and (percent_unique < unique_cut):
            nzv_cols.append(col)
            
    return nzv_cols

# %%
#def near_zero_var(df, freq_cut=19, unique_cut=10, save_metrics=False):
#    nzv_cols = []
#    rows = []
#    n = len(df)
#
#    for col in df.columns:
#        value_counts = df[col].value_counts(dropna=False)
#        n_unique = value_counts.size
#
#        zero_var = n_unique <= 1
#        if n_unique <= 1:
#            freq_ratio = np.inf
#        else:
#            freq_ratio = value_counts.iloc[0] / value_counts.iloc[1]
#
#        percent_unique = (n_unique / n) * 100 if n > 0 else 0
#        nzv = (freq_ratio > freq_cut) and (percent_unique <= unique_cut)
#
#        if zero_var or nzv:
#            nzv_cols.append(col)
#
#        if save_metrics:
#            rows.append({
#                "feature": col,
#                "freqRatio": freq_ratio,
#                "percentUnique": percent_unique,
#                "zeroVar": zero_var,
#                "nzv": nzv
#            })
#
#    if save_metrics:
#        return nzv_cols, pd.DataFrame(rows).set_index("feature")
#    return nzv_cols

# %% [markdown]
# mRNA: Filtering variables with near-zero variance

# %%
mrna_data.shape
# Out:
# (176, 60616)

# %%
nzv_mrna = near_zero_var(mrna_data)

# %%
mrna_data = mrna_data.drop(columns=nzv_mrna)
mrna_data.shape
# Out:
# (176, 43404)

# %% [markdown]
# miRNA: Filtering variables with near-zero variance

# %%
mirna_data.shape
# Out:
# (176, 1881)

# %%
nzv_mirna = near_zero_var(mirna_data)

# %%
mirna_data = mirna_data.drop(columns=nzv_mirna)
mirna_data.shape
# Out:
# (176, 982)

# %%
#metrics_miRNA.tail(15)

# %% [markdown]
# ### Save transformed data

# %%
#mrna_data.to_csv('../../data/transformed_data/mrna_transformed.csv')

# %%
#mirna_data.to_csv('../../data/transformed_data/mirna_transformed.csv')

# %%
#meth_data.to_csv('../../data/transformed_data/meth_transformed.csv')

# %%
#clinical_data.to_csv('../../data/transformed_data/clinical_transformed.csv')

# %% [markdown]
# Convert pandas dataframes mrna_data and mirna_data to R dataframes

# %%
with conversion.localconverter(default_converter + pandas2ri.converter):
   mirna_data_r = conversion.py2rpy(mirna_data)

# %%
mrna_np = np.asfortranarray(mrna_data.to_numpy(dtype=np.float64))

# %%
mrna_r_matrix = ro.r["matrix"](ro.FloatVector(mrna_np.ravel(order="F")), nrow=mrna_np.shape[0],ncol=mrna_np.shape[1])
mrna_r_matrix = ro.r["rownames<-"](mrna_r_matrix, ro.StrVector(mrna_data.index.astype(str).tolist()))
mrna_r_matrix = ro.r["colnames<-"](mrna_r_matrix, ro.StrVector(mrna_data.columns.astype(str).tolist()))

# %% [markdown]
# near-zero variance from R

# %% [markdown]
# miRNA

# %%
ro.r["dim"](mirna_data_r)
# Out:
# <rpy2.robjects.vectors.IntVector object at 0x0000019385B19DC0> [RTYPES.INTSXP]
# R classes: ('integer',)
# [178, 1881]

# %% [markdown]
# drop near-zero variance columns from mirna_data

# %%
nzv_names_r_mirna = caret.nearZeroVar(mirna_data_r, names=True)
keep_cols = ro.r["setdiff"](ro.r["colnames"](mirna_data_r), nzv_names_r_mirna)
mirna_data_r = mirna_data_r.rx(True, keep_cols)

# %%
ro.r["dim"](mirna_data_r)
# Out:
# <rpy2.robjects.vectors.IntVector object at 0x0000019388297E80> [RTYPES.INTSXP]
# R classes: ('integer',)
# [178, 984]

# %% [markdown]
# mRNA

# %%
ro.r["dim"](mrna_r_matrix)
# Out:
# <rpy2.robjects.vectors.IntVector object at 0x000001945A09FFC0> [RTYPES.INTSXP]
# R classes: ('integer',)
# [178, 60660]

# %%
nzv_idx_r = caret.nearZeroVar(mrna_r_matrix, names=False)  # 1-based R indices
ncol = int(ro.r["ncol"](mrna_r_matrix)[0])

nzv_idx = set(int(i) for i in list(nzv_idx_r))
keep_idx = ro.IntVector([i for i in range(1, ncol + 1) if i not in nzv_idx])

mrna_data_r = mrna_r_matrix.rx(True, keep_idx)

# %%
ro.r["dim"](mrna_data_r)
# Out:
# <rpy2.robjects.vectors.IntVector object at 0x000001938958FC80> [RTYPES.INTSXP]
# R classes: ('integer',)
# [178, 43467]

# %% [markdown]
# # Normalization

# %% [markdown]
# Load transformed datasets

# %%
mrna_data = pd.read_csv('../../data/transformed_data/mrna_transformed.csv')
mirna_data = pd.read_csv('../../data/transformed_data/mirna_transformed.csv')
meth_data = pd.read_csv('../../data/transformed_data/meth_transformed.csv')

# %%
mrna_data.set_index('patient_id', inplace=True)
mirna_data.set_index('patient_id', inplace=True)
meth_data.set_index('patient_id', inplace=True)

# %% [markdown]
# ### mRNA and miRNA: Log2(x+1) Transformation

# %%
mrna_data_lg2 = np.log2(mrna_data + 1)
mirna_data_lg2 = np.log2(mirna_data + 1)

# %% [markdown]
# ### mRNA and miRNA: Variance Stabilization Normalization (VSN)

# %% [markdown]
# Import vsn and base R package

# %%
#limma = rpackages.importr('limma')
#base = rpackages.importr("base")

# %% [markdown]
# Convert dataframe to matrix

# %%
print(ro.r["class"](mirna_data_r)[0])
# Out:
# data.frame

# %%
mirna_matrix = base.as_matrix(mirna_data_r)

# %%
mrna_matrix = base.as_matrix(mrna_data_r)

# %%
mirna_matrix_t = ro.r['t'](mirna_matrix)

# %%
mirna_data_vsn_t = limma.normalizeVSN(mirna_matrix_t)
# Out:
# R callback write-console: vsn2: 984 x 178 matrix (1 stratum).
#
# R callback write-console: Please use 'meanSdPlot' to verify the fit.

# %%
mirna_data_vsn = ro.r['t'](mirna_data_vsn_t)

# %%
mrna_matrix_t = ro.r['t'](mrna_matrix)

# %%
mrna_vsn_t = limma.normalizeVSN(mrna_matrix_t)
# Out:
# R callback write-console: vsn2: 43467 x 178 matrix (1 stratum).
#
# R callback write-console: Please use 'meanSdPlot' to verify the fit.

# %%
mrna_data_vsn = ro.r['t'](mrna_vsn_t)

# %% [markdown]
# Convert mirna_data_vsn back to pandas dataframe

# %%
with conversion.localconverter(default_converter + pandas2ri.converter):
   mirna_data_vsn_df = conversion.rpy2py(mirna_data_vsn)

# %% [markdown]
# - falta converter mrna_data_vsn para pandas

# %% [markdown]
# ### DNA Methylation: Convert Beta-Values into M-values

# %%
epsilon = 1e-6
meth_beta = meth_data.clip(lower=epsilon, upper = 1 - epsilon)
meth_data = np.log2(meth_beta / (1 - meth_beta))

# %%
#Calculate the variance of each feature across all patients


#mrna_variances = mrna_data.var(axis=0)
#mirna_variances = mirna_data.var(axis=0)
#meth_variances = meth_data.var(axis=0, skipna=True)

#Select the top Highly Variable Features


#top_5000_mrna = mrna_variances.nlargest(5000).index
#mrna_data = mrna_data[top_5000_mrna]

#top_500_mirna = mirna_variances.nlargest(500).index
#mirna_data = mirna_data[top_500_mirna]

#top_10000_meth = meth_variances.nlargest(10000).index
#meth_data = meth_data[top_10000_meth]

# %% [markdown]
# ## UMAP Function

# %%
def umap_function(df, n_neighbors=15, min_dist=0.1, metric='euclidean', random_state=42, title='UMAP Projection'):
    umap_model = umap.UMAP(n_neighbors=n_neighbors, min_dist=min_dist, metric=metric, random_state=random_state)
    embedding = umap_model.fit_transform(df)
    plt.figure(figsize=(6, 5))
    plt.scatter(embedding[:, 0], embedding[:, 1], s=18, alpha = 0.8)
    plt.title(title)
    plt.xlabel('UMAP 1')
    plt.ylabel('UMAP 2')
    plt.show()
    return embedding

# %% [markdown]
# ### UMAP on mrna_data, mrna_data_lg2

# %%
embedding_mrna_data = umap_function(mrna_data, title = 'UMAP - mRNA Raw')
embedding_mrna_lg2 = umap_function(mrna_data_lg2, title = 'UMAP - mRNA log2')

# %% [markdown]
# ### UMAP on mrna_data_lg2 colored by tumor_subtype

# %%
clinical_data.set_index('bcr_patient_barcode', inplace=True)
mrna_data_lg2 = mrna_data_lg2.reindex(clinical_data.index)

# %%
umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean', random_state=42)
embedding_mrna_lg2 = umap_model.fit_transform(mrna_data_lg2)
# Out:
# c:\Users\ritam\Desktop\thesis_rita\mofa_venv\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=embedding_mrna_lg2[:, 0], y=embedding_mrna_lg2[:, 1], hue=clinical_data['tumor_subtype'], palette = 'Set1',s=40, alpha=0.8)
plt.title('UMAP - mRNA log2 colored by tumor subtypes')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.legend(title='Tumor Subtype', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### UMAP on mirna_data, mirna_data_vsn and mirna_data_lg2

# %%
embedding_mirna_data = umap_function(mirna_data, title='UMAP - miRNA Raw')
#embedding_mirna_vsn = umap_function(mirna_data_vsn_df, title='UMAP - miRNA VSN')
embedding_mirna_lg2 = umap_function(mirna_data_lg2, title='UMAP - miRNA log2')

# %% [markdown]
# Feature Selection

# %%
mrna_data_lg2 = mrna_data_lg2.reindex(clinical_data.index)

# %%
ductal_mask = clinical_data['tumor_subtype'] == 'Ductal Type'
other_mask = clinical_data['tumor_subtype'] == 'Other Type'

ductal_data = mrna_data_lg2[ductal_mask]
other_data = mrna_data_lg2[other_mask]

# %% [markdown]
# Run t-test

# %%
t_stats, p_values = stats.ttest_ind(ductal_data, other_data, axis=0, equal_var=False, nan_policy='omit')
p_values = np.nan_to_num(p_values, nan=1.0)

# %% [markdown]
# Apply B-H correction

# %%
reject, pvals_corrected, _, _ = multipletests(p_values, alpha=0.2, method='fdr_bh')

# %% [markdown]
# Filter mrna_data to keep only significant genes based on test

# %%
selected_genes = mrna_data_lg2.columns[reject]
mrna_data_lg2_selected = mrna_data_lg2[selected_genes]

# %%
print(f"Original number of genes: {mrna_data_lg2.shape[1]}")
print(f"Genes with adjusted p-values < 0.2: {len(selected_genes)}")
# Out:
# Original number of genes: 43467
# Genes with adjusted p-values < 0.2: 10215

# %%
mrna_data_lg2 = mrna_data_lg2.reindex(clinical_data.index)

umap_model = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='euclidean', random_state=42)
embedding_mrna_lg2 = umap_model.fit_transform(mrna_data_lg2)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=embedding_mrna_lg2[:, 0], y=embedding_mrna_lg2[:, 1], hue=clinical_data['tumor_subtype'], palette = 'Set1',s=40, alpha=0.8)
plt.title('UMAP - mRNA log2 colored by tumor subtypes')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.legend(title='Tumor Subtype', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save the processed data for MOFA

# %%
mrna_data.to_csv('../../data/transformed_data/mofa_data/mrna_transformed_mofa.csv')
mirna_data.to_csv('../../data/transformed_data/mofa_data/mirna_transformed_mofa.csv')
meth_data.to_csv('../../data/transformed_data/mofa_data/meth_transformed_mofa.csv')
clinical_data.to_csv('../../data/transformed_data/mofa_data/clinical_transformed_mofa.csv', index=False)
