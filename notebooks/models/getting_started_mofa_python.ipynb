# %% [markdown]
# # MOFA+: training a model in Python
# Author: Ricard Argelaguet.
# Affiliation: European Bioinformatics Institute, Cambridge, UK.
# Date: 13/11/2019

# %% [markdown]
# This notebook contains a detailed tutorial on how to train MOFA using Python.
# A template script to run the code below can be found [here](https://github.com/bioFAM/MOFA2/tree/master/inst/scripts).

# %% [markdown]
# ## 1) Load libraries

# %%
from mofapy2.run.entry_point import entry_point
import pandas as pd
import numpy as np

# initialise the entry point
ent = entry_point()
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################

# %% [markdown]
# ## 2) Load data
#
# To create a MOFA+ object you need to specify four dimensions: samples (cells), features, view(s) and group(s). MOFA objects can be created from a wide range of input formats:
#
# ### 2.1) pandas data.frame format
# A pandas data.frame with columns `sample`, `group`, `feature`, `view`, `value`.  This is the most intuitive format, as it summarises all omics/groups in a single data structure. Also, there is no need to add rows that correspond to missing data.
#
# For example:
# ```
# sample   group   feature    value   view
# sample1  groupA  gene1      2.8044  RNA
# sample1  groupA  gene3      2.2069  RNA
# sample2  groupB  gene2      0.1454  RNA
# sample2  groupB  gene1      2.7021  RNA
# sample2  groupB  promoter1  3.8618  Methylation
# sample3  groupB  promoter2  3.2545  Methylation
# sample3  groupB  promoter3  1.5014  Methylation
# ```

# %% [markdown]
# Here we load a simulated data set with the following dimensions:

# %%
D = [1000,1000] # Number of features per view
M = len(D)      # Number of views
K = 5           # Number of factors
N = [100,100]   # Number of samples per group
G = len(N)      # Number of groups

data_dt = pd.read_csv("http://ftp.ebi.ac.uk/pub/databases/mofa/getting_started/data.txt.gz", sep="\t")
data_dt.head()
# Out:
#              sample    group           feature    view  value
# 0  sample_0_group_0  group_0  feature_0_view_0  view_0  -2.05
# 1  sample_1_group_0  group_0  feature_0_view_0  view_0   0.10
# 2  sample_2_group_0  group_0  feature_0_view_0  view_0   1.44
# 3  sample_3_group_0  group_0  feature_0_view_0  view_0  -0.28
# 4  sample_4_group_0  group_0  feature_0_view_0  view_0  -0.88

# %% [markdown]
# ### 2.2) List of matrices
# A nested list of numpy arrays, where the first index refers to the view and the second index refers to the group. Samples are stored in the rows and features are stored in the columns. All views for a given group G must have the same samples in the rows. If there is any sample that is missing a particular view, the column needs to be filled with NAs.

# %% [markdown]
# Loading the same data above in matrix format:

# %%
data_prefix = "http://ftp.ebi.ac.uk/pub/databases/mofa/getting_started"
data_mat = [[None for g in range(G)] for m in range(M)]
for m in range(M):
    for g in range(G):
        data_mat[m][g] = np.loadtxt("%s/%d_%d.txt.gz" % (data_prefix,m,g), delimiter="\t")

# %% [markdown]
# ### 2.3 Define data options
# - **scale_views**: if views have different ranges/variances, it is good practice to scale each view to unit variance. Default is False

# %%
ent.set_data_options(
    scale_views = False
)

# %% [markdown]
# ### 2.4) Add the data to the model
#
# This has to be run after defining the data options
# - **likelihoods**: a list of strings, either "gaussian" (default), "poisson" or "bernoulli"

# %%
# option 1: data.frame format
ent.set_data_df(data_dt, likelihoods = ["gaussian","gaussian"])

# option 2: nested matrix format
ent.set_data_matrix(data_mat, likelihoods = ["gaussian","gaussian"])
# Out:
# Loaded group='group_0' view='view_0' with N=100 samples and D=1000 features...
# Loaded group='group_0' view='view_1' with N=100 samples and D=1000 features...
# Loaded group='group_1' view='view_0' with N=100 samples and D=1000 features...
# Loaded group='group_1' view='view_1' with N=100 samples and D=1000 features...
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=100 samples and D=1000 features...
# Successfully loaded view='view0' group='group1' with N=100 samples and D=1000 features...
# Successfully loaded view='view1' group='group0' with N=100 samples and D=1000 features...
# Successfully loaded view='view1' group='group1' with N=100 samples and D=1000 features...

# %% [markdown]
# ## 3) Set model options
#
# - **factors**: number of factors
# - **spikeslab_weights**: use spike-slab sparsity prior in the weights? default is TRUE
# - **ard_weights**: use ARD prior in the weights? Default is TRUE if using multiple views.
#
# Only change the default model options if you are familiar with the underlying mathematical model!

# %%
ent.set_model_options(
    factors = 10, 
    spikeslab_weights = True, 
    ard_weights = True
)
# Out:
# WARNING: 'ard_factors' in model_options should be set to True if using multiple groups unless you are using MEFISTO
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian

# %% [markdown]
# ## 4) Set training options
#
# - **convergence_mode**: "fast" (default), "medium", "slow".
# - **dropR2**: minimum variance explained criteria to drop factors while training
# - **gpu_mode**: use GPU? (needs cupy installed and a functional GPU, see https://biofam.github.io/MOFA2/gpu_training.html)
# - **seed**: random seed

# %%
ent.set_train_options(
    convergence_mode = "fast", 
    dropR2 = 0.001, 
    gpu_mode = True, 
    seed = 1
)
# Out:
# GPU mode is activated, but GPU not found... switching to CPU mode
# For GPU mode, you need:
# 1 - Make sure that you are running MOFA+ on a machine with an NVIDIA GPU
# 2 - Install CUPY following instructions on https://docs-cupy.chainer.org/en/stable/install.html

# %% [markdown]
# ## 6) Build and train the MOFA object
#
# After training, the model will be saved as an hdf5 file

# %%
ent.build()

ent.run()

# Save the output
ent.save(outfile=None)
# Out:
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -3106942.29
#
# Iteration 1: time=0.11, ELBO=-569770.65, deltaELBO=2537171.640 (81.66137009%), Factors=9
# Iteration 2: time=0.13, ELBO=-478708.91, deltaELBO=91061.734 (2.93091166%), Factors=8
# Iteration 3: time=0.10, ELBO=-470816.31, deltaELBO=7892.606 (0.25403130%), Factors=7
# Iteration 4: time=0.09, ELBO=-466093.96, deltaELBO=4722.344 (0.15199330%), Factors=6
# Iteration 5: time=0.10, ELBO=-462226.03, deltaELBO=3867.936 (0.12449333%), Factors=5
# Iteration 6: time=0.08, ELBO=-461127.26, deltaELBO=1098.769 (0.03536497%), Factors=5
# Iteration 7: time=0.09, ELBO=-460473.27, deltaELBO=653.989 (0.02104927%), Factors=5
# Iteration 8: time=0.07, ELBO=-460013.76, deltaELBO=459.507 (0.01478969%), Factors=5
# Iteration 9: time=0.09, ELBO=-459632.76, deltaELBO=381.000 (0.01226286%), Factors=5
# Iteration 10: time=0.07, ELBO=-459301.11, deltaELBO=331.648 (0.01067443%), Factors=5
# Iteration 11: time=0.08, ELBO=-459020.25, deltaELBO=280.865 (0.00903992%), Factors=5
# Iteration 12: time=0.09, ELBO=-458788.15, deltaELBO=232.103 (0.00747046%), Factors=5
# Iteration 13: time=0.09, ELBO=-458595.02, deltaELBO=193.131 (0.00621612%), Factors=5
# Iteration 14: time=0.10, ELBO=-458429.37, deltaELBO=165.650 (0.00533162%), Factors=5
# Iteration 15: time=0.08, ELBO=-458282.82, deltaELBO=146.545 (0.00471670%), Factors=5
# Iteration 16: time=0.10, ELBO=-458148.44, deltaELBO=134.379 (0.00432514%), Factors=5
# Iteration 17: time=0.09, ELBO=-458020.72, deltaELBO=127.720 (0.00411078%), Factors=5
# Iteration 18: time=0.10, ELBO=-457896.09, deltaELBO=124.629 (0.00401130%), Factors=5
# Iteration 19: time=0.09, ELBO=-457772.25, deltaELBO=123.841 (0.00398593%), Factors=5
# Iteration 20: time=0.09, ELBO=-457647.48, deltaELBO=124.768 (0.00401578%), Factors=5
# Iteration 21: time=0.09, ELBO=-457520.33, deltaELBO=127.152 (0.00409251%), Factors=5
# Iteration 22: time=0.08, ELBO=-457389.81, deltaELBO=130.524 (0.00420104%), Factors=5
# Iteration 23: time=0.08, ELBO=-457255.84, deltaELBO=133.964 (0.00431175%), Factors=5
# Iteration 24: time=0.07, ELBO=-457119.12, deltaELBO=136.720 (0.00440048%), Factors=5
# Iteration 25: time=0.09, ELBO=-456978.80, deltaELBO=140.322 (0.00451640%), Factors=5
# Iteration 26: time=0.10, ELBO=-456833.26, deltaELBO=145.543 (0.00468444%), Factors=5
# Iteration 27: time=0.08, ELBO=-456687.42, deltaELBO=145.838 (0.00469392%), Factors=5
# Iteration 28: time=0.08, ELBO=-456552.61, deltaELBO=134.808 (0.00433893%), Factors=5
# Iteration 29: time=0.09, ELBO=-456437.13, deltaELBO=115.484 (0.00371696%), Factors=5
# Iteration 30: time=0.09, ELBO=-456341.84, deltaELBO=95.292 (0.00306706%), Factors=5
# Iteration 31: time=0.08, ELBO=-456262.84, deltaELBO=78.997 (0.00254261%), Factors=5
# Iteration 32: time=0.07, ELBO=-456194.40, deltaELBO=68.436 (0.00220268%), Factors=5
# Iteration 33: time=0.08, ELBO=-456132.30, deltaELBO=62.108 (0.00199902%), Factors=5
# Iteration 34: time=0.08, ELBO=-456074.58, deltaELBO=57.719 (0.00185774%), Factors=5
# Iteration 35: time=0.09, ELBO=-456020.98, deltaELBO=53.601 (0.00172519%), Factors=5
# Iteration 36: time=0.08, ELBO=-455971.83, deltaELBO=49.144 (0.00158175%), Factors=5
# Iteration 37: time=0.08, ELBO=-455927.12, deltaELBO=44.717 (0.00143927%), Factors=5
# Iteration 38: time=0.08, ELBO=-455886.25, deltaELBO=40.870 (0.00131543%), Factors=5
# Iteration 39: time=0.08, ELBO=-455848.47, deltaELBO=37.771 (0.00121570%), Factors=5
# Iteration 40: time=0.10, ELBO=-455813.13, deltaELBO=35.346 (0.00113765%), Factors=5
# Iteration 41: time=0.10, ELBO=-455779.66, deltaELBO=33.470 (0.00107725%), Factors=5
# Iteration 42: time=0.09, ELBO=-455747.64, deltaELBO=32.017 (0.00103051%), Factors=5
# Iteration 43: time=0.08, ELBO=-455716.76, deltaELBO=30.877 (0.00099381%), Factors=5
# Iteration 44: time=0.08, ELBO=-455686.81, deltaELBO=29.957 (0.00096420%), Factors=5
# Iteration 45: time=0.08, ELBO=-455657.62, deltaELBO=29.191 (0.00093953%), Factors=5
# Iteration 46: time=0.08, ELBO=-455629.09, deltaELBO=28.532 (0.00091832%), Factors=5
# Iteration 47: time=0.08, ELBO=-455601.13, deltaELBO=27.951 (0.00089964%), Factors=5
# Iteration 48: time=0.08, ELBO=-455573.70, deltaELBO=27.432 (0.00088294%), Factors=5
# Iteration 49: time=0.08, ELBO=-455546.74, deltaELBO=26.964 (0.00086787%), Factors=5
# Iteration 50: time=0.09, ELBO=-452306.83, deltaELBO=3239.904 (0.10427950%), Factors=5
# Iteration 51: time=0.08, ELBO=-452245.55, deltaELBO=61.286 (0.00197255%), Factors=5
# Iteration 52: time=0.08, ELBO=-452206.36, deltaELBO=39.185 (0.00126121%), Factors=5
# Iteration 53: time=0.08, ELBO=-452175.34, deltaELBO=31.023 (0.00099852%), Factors=5
# Iteration 54: time=0.08, ELBO=-452149.15, deltaELBO=26.186 (0.00084283%), Factors=5
# Iteration 55: time=0.09, ELBO=-452125.53, deltaELBO=23.622 (0.00076028%), Factors=5
# Iteration 56: time=0.08, ELBO=-452103.27, deltaELBO=22.260 (0.00071648%), Factors=5
# Iteration 57: time=0.08, ELBO=-452081.80, deltaELBO=21.475 (0.00069119%), Factors=5
# Iteration 58: time=0.08, ELBO=-452060.83, deltaELBO=20.961 (0.00067465%), Factors=5
# Iteration 59: time=0.09, ELBO=-452040.25, deltaELBO=20.580 (0.00066240%), Factors=5
# Iteration 60: time=0.09, ELBO=-452019.98, deltaELBO=20.270 (0.00065241%), Factors=5
# Iteration 61: time=0.09, ELBO=-451999.98, deltaELBO=20.000 (0.00064374%), Factors=5
# Iteration 62: time=0.09, ELBO=-451980.23, deltaELBO=19.759 (0.00063596%), Factors=5
# Iteration 63: time=0.10, ELBO=-451960.69, deltaELBO=19.539 (0.00062888%), Factors=5
# Iteration 64: time=0.09, ELBO=-451941.35, deltaELBO=19.338 (0.00062241%), Factors=5
# Iteration 65: time=0.08, ELBO=-451922.19, deltaELBO=19.155 (0.00061653%), Factors=5
# Iteration 66: time=0.08, ELBO=-451903.20, deltaELBO=18.991 (0.00061124%), Factors=5
# Iteration 67: time=0.08, ELBO=-451884.36, deltaELBO=18.846 (0.00060657%), Factors=5
# Iteration 68: time=0.08, ELBO=-451865.63, deltaELBO=18.721 (0.00060257%), Factors=5
# Iteration 69: time=0.09, ELBO=-451847.01, deltaELBO=18.620 (0.00059931%), Factors=5
# Iteration 70: time=0.07, ELBO=-451828.47, deltaELBO=18.546 (0.00059691%), Factors=5
# Iteration 71: time=0.09, ELBO=-451809.97, deltaELBO=18.502 (0.00059550%), Factors=5
# Iteration 72: time=0.09, ELBO=-451791.47, deltaELBO=18.495 (0.00059528%), Factors=5
# Iteration 73: time=0.08, ELBO=-451772.94, deltaELBO=18.532 (0.00059646%), Factors=5
# Iteration 74: time=0.09, ELBO=-451754.32, deltaELBO=18.621 (0.00059933%), Factors=5
# Iteration 75: time=0.08, ELBO=-451735.55, deltaELBO=18.771 (0.00060416%), Factors=5
# Iteration 76: time=0.08, ELBO=-451716.56, deltaELBO=18.992 (0.00061128%), Factors=5
# Iteration 77: time=0.08, ELBO=-451697.26, deltaELBO=19.292 (0.00062092%), Factors=5
# Iteration 78: time=0.09, ELBO=-451677.59, deltaELBO=19.673 (0.00063320%), Factors=5
# Iteration 79: time=0.09, ELBO=-451657.46, deltaELBO=20.136 (0.00064810%), Factors=5
# Iteration 80: time=0.08, ELBO=-451636.78, deltaELBO=20.676 (0.00066549%), Factors=5
# Iteration 81: time=0.08, ELBO=-451615.49, deltaELBO=21.289 (0.00068522%), Factors=5
# Iteration 82: time=0.09, ELBO=-451593.52, deltaELBO=21.974 (0.00070725%), Factors=5
# Iteration 83: time=0.08, ELBO=-451570.78, deltaELBO=22.733 (0.00073170%), Factors=5
# Iteration 84: time=0.08, ELBO=-451547.20, deltaELBO=23.580 (0.00075895%), Factors=5
# Iteration 85: time=0.08, ELBO=-451522.66, deltaELBO=24.543 (0.00078994%), Factors=5
# Iteration 86: time=0.09, ELBO=-451496.99, deltaELBO=25.669 (0.00082617%), Factors=5
# Iteration 87: time=0.08, ELBO=-451469.98, deltaELBO=27.011 (0.00086936%), Factors=5
# Iteration 88: time=0.08, ELBO=-451441.37, deltaELBO=28.610 (0.00092086%), Factors=5
# Iteration 89: time=0.09, ELBO=-451410.87, deltaELBO=30.496 (0.00098153%), Factors=5
# Iteration 90: time=0.08, ELBO=-451378.17, deltaELBO=32.706 (0.00105268%), Factors=5
# Iteration 91: time=0.08, ELBO=-451342.85, deltaELBO=35.322 (0.00113687%), Factors=5
# Iteration 92: time=0.08, ELBO=-451304.40, deltaELBO=38.450 (0.00123754%), Factors=5
# Iteration 93: time=0.07, ELBO=-451262.23, deltaELBO=42.168 (0.00135723%), Factors=5
# Iteration 94: time=0.07, ELBO=-451215.74, deltaELBO=46.490 (0.00149633%), Factors=5
# Iteration 95: time=0.08, ELBO=-451164.30, deltaELBO=51.435 (0.00165548%), Factors=5
# Iteration 96: time=0.08, ELBO=-451107.09, deltaELBO=57.212 (0.00184143%), Factors=5
# Iteration 97: time=0.08, ELBO=-451042.80, deltaELBO=64.288 (0.00206918%), Factors=5
# Iteration 98: time=0.07, ELBO=-450970.30, deltaELBO=72.502 (0.00233353%), Factors=5
# Iteration 99: time=0.08, ELBO=-450890.91, deltaELBO=79.391 (0.00255527%), Factors=5
# Iteration 100: time=0.09, ELBO=-450809.58, deltaELBO=81.326 (0.00261757%), Factors=5
# Iteration 101: time=0.08, ELBO=-450733.75, deltaELBO=75.833 (0.00244077%), Factors=5
# Iteration 102: time=0.08, ELBO=-450669.56, deltaELBO=64.187 (0.00206592%), Factors=5
# Iteration 103: time=0.09, ELBO=-450616.69, deltaELBO=52.878 (0.00170194%), Factors=5
# Iteration 104: time=0.08, ELBO=-450569.22, deltaELBO=47.468 (0.00152781%), Factors=5
# Iteration 105: time=0.08, ELBO=-450521.55, deltaELBO=47.667 (0.00153420%), Factors=5
# Iteration 106: time=0.08, ELBO=-450469.83, deltaELBO=51.723 (0.00166474%), Factors=5
# Iteration 107: time=0.08, ELBO=-450411.82, deltaELBO=58.009 (0.00186708%), Factors=5
# Iteration 108: time=0.08, ELBO=-450349.14, deltaELBO=62.681 (0.00201744%), Factors=5
# Iteration 109: time=0.11, ELBO=-450288.77, deltaELBO=60.373 (0.00194315%), Factors=5
# Iteration 110: time=0.09, ELBO=-450238.06, deltaELBO=50.710 (0.00163214%), Factors=5
# Iteration 111: time=0.09, ELBO=-450202.01, deltaELBO=36.048 (0.00116022%), Factors=5
# Iteration 112: time=0.10, ELBO=-450179.74, deltaELBO=22.270 (0.00071679%), Factors=5
# Iteration 113: time=0.09, ELBO=-450166.05, deltaELBO=13.693 (0.00044073%), Factors=5
# Iteration 114: time=0.08, ELBO=-450156.43, deltaELBO=9.614 (0.00030943%), Factors=5
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# No output file name provided as a training options or to the save method. Saving to /tmp\mofa_20260218-115024.hdf5 .
# Output directory does not exist, creating it...
# Saving model in /tmp\mofa_20260218-115024.hdf5...

# %% [markdown]
# ## 7) Downstream analysis
#
# This finishes the tutorial on how to train a MOFA model from python. To continue with the downstream analysis you can either use the [mofax](https://github.com/gtca/mofax) python package or the [MOFA2](https://www.bioconductor.org/packages/release/bioc/html/MOFA2.html) R package. Please, visit our [tutorials](https://biofam.github.io/MOFA2/tutorials.html) webpage for more information.
